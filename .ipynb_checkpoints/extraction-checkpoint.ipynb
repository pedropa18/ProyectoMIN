# %% [markdown]
# Instalando pymongo en Jupyter Notebook para poder conectarme a la BD

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\pedro\anaconda3\lib\site-packages (4.11.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\pedro\anaconda3\lib\site-packages (from pymongo) (2.7.0)

# %% [markdown]
# Importando pymongo para comprobar que se ha instalando y ver que versión es

# %%
import pymongo
print(pymongo.__version__)
# Out:
# 4.11.2

# %% [markdown]
# Estableciendo la conexión al servidor para acceder a la BD

# %%
username = "pedro"
password = "Zela2720"

mongo_uri = f"mongodb://{username}:{password}@srvmongo.fmarch.es:27017"
myclient = pymongo.MongoClient(mongo_uri)

mydb1 = myclient["culturales"]
mydb2 = myclient["reservas"]

# %% [markdown]
# Listar las bases de datos del sistema

# %%
print(myclient.list_database_names())
# Out:
# ['Aemet', 'Android', 'BibliotecaPatio', 'Calendario_laboral', 'DatalabMonitor', 'DrupalWeb', 'Filmin', 'GoogleAnalytics', 'GooglePlaces', 'GraphQL', 'LuisPhD', 'Medium', 'OpenWeatherMap', 'PodcastsTransitor', 'PreservacionMonitor', 'Queues', 'Wowza', 'YouTube', 'admin', 'adquisiciones', 'bibliotecas', 'config', 'culturales', 'db_linz', 'exposiciones', 'facebook', 'instagram', 'islandora', 'local', 'newsletters', 'notificaciones', 'reservas', 'tripadvisor', 'twitter', 'vimeo', 'vocabularios']

# %% [markdown]
# Comprobación de que existe la base de datos

# %%
dblist = myclient.list_database_names()
if "reservas" in dblist:
        print("The DB exists.")
# Out:
# The DB exists.

# %% [markdown]
# Comprobar la existencia de una colección

# %%
collist = mydb1.list_collection_names()
if "actos" in collist:
    print("The collection exists.")
# Out:
# The collection exists.

# %% [markdown]
# Creo mis colecciones y observo los campos de cada una de ellas

# %%
mycol1 = mydb1["actos"]
mycol2 = mydb2["resumenv2"]

coleccion1 = mycol1.find_one()
coleccion2 = mycol2.find_one()

print("Campos de la colección_1: ", coleccion1.keys())
print("Campos de la colección_2: ", coleccion2.keys())
# Out:
# Campos de la colección_1:  dict_keys(['_id', 'idacto', 'SalonAuxiliarLleno', 'SalonPrincipalLleno', 'VisitantesCafeteria', 'VisitantesSalonActos', 'VisitantesSalonAzul', 'VisitantesTotales', 'cancelado', 'fecha', 'formato', 'grupo', 'idGrupoActo', 'idSede', 'nombre', 'participantes', 'thumbnail', 'tipo', 'urlAudio', 'humidity', 'temp', 'weather_description', 'weather_icon', 'weather_id', 'weather_main', 'wind_deg', 'wind_speed', 'pathWeb'])
# Campos de la colección_2:  dict_keys(['_id', 'idActo', 'fecha', 'Internet_Validadas', 'Total_Validadas', 'grupo', 'nombre', 'formato', 'idSede', 'QuedanParaCola', 'AsistentesCola', 'usuarios0', 'usuarios2_4', 'usuarios5_10', 'usuariosM10'])

# %% [markdown]
# Muestra la lista de datos con los campos que me interesan dentro de un rango de fechas (Temporada 23/24)

# %%
from datetime import datetime # Importamos el módulo datetime

# Generamos en ese formato el rango de fechas
fecha_inicio = datetime(2023, 9, 1)
fecha_fin = datetime(2024, 7, 31, 23, 59, 59)

# Creamos la query como intervalo de fechas para extraer los datos en ese rango
query = {
    "fecha": {"$gte" : fecha_inicio, "$lte" : fecha_fin},
    "idSede": "1"  # Filtrar por idSede = 1 (Madrid)
}
# Proyección para mostrar solamente los campos que me interesan
projection = {
    "_id" : 0,
    "idacto": 1,
    "VisitantesTotales": 1,
    "cancelado": 1,
    "formato": 1,
    "nombre": 1,
    "tipo": 1
}

resultados = list(mycol1.find(query, projection))

for x in resultados:
    print(x)
# Out:
# {'idacto': 105353, 'VisitantesTotales': '0', 'cancelado': 0, 'formato': 'Actos especiales', 'nombre': 'Presentación de la temporada de conciertos 2023-24', 'tipo': 'Concierto'}
# {'idacto': 105037, 'VisitantesTotales': '343', 'cancelado': 0, 'formato': 'Aula de (Re)estrenos', 'nombre': 'Aula de (Re)estrenos (122). Folclore y poesía: la polifonía española', 'tipo': 'Concierto'}
# {'idacto': 105056, 'VisitantesTotales': '326', 'cancelado': 0, 'formato': 'Acto inaugural', 'nombre': 'Inauguración de la exposición <em>Antes de América. Fuentes originarias en la cultura moderna</em>', 'tipo': 'Concierto'}
# {'idacto': 105032, 'VisitantesTotales': '330', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'De tristes y tangos', 'tipo': 'Concierto'}
# {'idacto': 105066, 'VisitantesTotales': '347', 'cancelado': 0, 'formato': 'Teatro Musical de Cámara', 'nombre': 'Grilletta e Porsugnacco', 'tipo': 'Concierto'}
# {'idacto': 105065, 'VisitantesTotales': '333', 'cancelado': 0, 'formato': 'Teatro Musical de Cámara', 'nombre': 'Grilletta e Porsugnacco', 'tipo': 'Concierto'}
# {'idacto': 105064, 'VisitantesTotales': '373', 'cancelado': 0, 'formato': 'Teatro Musical de Cámara', 'nombre': 'Grilletta e Porsugnacco', 'tipo': 'Concierto'}
# {'idacto': 105063, 'VisitantesTotales': '365', 'cancelado': 0, 'formato': 'Teatro Musical de Cámara', 'nombre': '<em>Grilletta e Porsugnacco</em> de Johann Adolph Hasse', 'tipo': 'Concierto'}
# {'idacto': 105076, 'VisitantesTotales': '345', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Curtis on Tour: Sexteto de cuerda', 'tipo': 'Concierto'}
# {'idacto': 105027, 'VisitantesTotales': '318', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'Ensoñación nocturna', 'tipo': 'Concierto'}
# {'idacto': 105278, 'VisitantesTotales': '396', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Séneca', 'tipo': 'Conferencia'}
# {'idacto': 105077, 'VisitantesTotales': '282', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Curtis on Tour: Sexteto de cuerda', 'tipo': 'Concierto'}
# {'idacto': 105033, 'VisitantesTotales': '332', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Teclados sin fronteras', 'tipo': 'Concierto'}
# {'idacto': 105086, 'VisitantesTotales': '304', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Cristina Cordero y Juan Barahona', 'tipo': 'Concierto'}
# {'idacto': 105274, 'VisitantesTotales': '174', 'cancelado': 0, 'formato': 'La cuestión palpitante', 'nombre': 'La salud pública en Europa', 'tipo': 'Conferencia'}
# {'idacto': 105087, 'VisitantesTotales': '282', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Cristina Cordero y Juan Barahona', 'tipo': 'Concierto'}
# {'idacto': 105279, 'VisitantesTotales': '337', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Epicteto', 'tipo': 'Conferencia'}
# {'idacto': 105028, 'VisitantesTotales': '305', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'La patria soñada', 'tipo': 'Concierto'}
# {'idacto': 105381, 'VisitantesTotales': '61', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': '<em>El secreto de los incas</em>', 'tipo': 'Conferencia'}
# {'idacto': 105370, 'VisitantesTotales': '27', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': '<em>Wara Wara</em>', 'tipo': 'Conferencia'}
# {'idacto': 105280, 'VisitantesTotales': '251', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Marco Aurelio', 'tipo': 'Conferencia'}
# {'idacto': 105253, 'VisitantesTotales': '348', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>La senda del crimen </em>(1930) de Archie Mayo', 'tipo': 'Conferencia'}
# {'idacto': 105254, 'VisitantesTotales': '368', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>La senda del crimen </em>(1930) de Archie Mayo', 'tipo': 'Conferencia'}
# {'idacto': 105034, 'VisitantesTotales': '340', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Semillas europeas en Latinoamérica', 'tipo': 'Concierto'}
# {'idacto': 105071, 'VisitantesTotales': '282', 'cancelado': 0, 'formato': 'Viernes Temáticos', 'nombre': 'Cupido, amor travieso', 'tipo': 'Concierto'}
# {'idacto': 105070, 'VisitantesTotales': '285', 'cancelado': 0, 'formato': 'Viernes Temáticos', 'nombre': 'Cupido, amor travieso', 'tipo': 'Concierto'}
# {'idacto': 105080, 'VisitantesTotales': '308', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Irene Roldán', 'tipo': 'Concierto'}
# {'idacto': 105276, 'VisitantesTotales': '82', 'cancelado': 0, 'formato': 'Memorias de la Fundación', 'nombre': 'María Rosa Calvo-Manzano', 'tipo': 'Conferencia'}
# {'idacto': 105081, 'VisitantesTotales': '239', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Irene Roldán', 'tipo': 'Concierto'}
# {'idacto': 105250, 'VisitantesTotales': '181', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Los dinosaurios voladores', 'tipo': 'Conferencia'}
# {'idacto': 105029, 'VisitantesTotales': '320', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'El desarraigo del errabundo', 'tipo': 'Concierto'}
# {'idacto': 105249, 'VisitantesTotales': '148', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'El vuelo de las primeras aves', 'tipo': 'Conferencia'}
# {'idacto': 105404, 'VisitantesTotales': '0', 'cancelado': 0, 'formato': 'La Biblioteca invita', 'nombre': '<p><em>Antes de Am&eacute;rica</em>. La voz de los protagonistas</p> ', 'tipo': 'Conferencia'}
# {'idacto': 105035, 'VisitantesTotales': '371', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Nanas y habaneras latinas', 'tipo': 'Concierto'}
# {'idacto': 105078, 'VisitantesTotales': '292', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Rafael Quirant', 'tipo': 'Concierto'}
# {'idacto': 105377, 'VisitantesTotales': '76', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': '<em>Deseada</em>', 'tipo': 'Conferencia'}
# {'idacto': 105373, 'VisitantesTotales': '64', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': '<em>¡Que Viva México!</em>', 'tipo': 'Conferencia'}
# {'idacto': 105079, 'VisitantesTotales': '272', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Rafael Quirant', 'tipo': 'Concierto'}
# {'idacto': 105251, 'VisitantesTotales': '151', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Las aves modernas: origen y nuevas claves evolutivas', 'tipo': 'Conferencia'}
# {'idacto': 105030, 'VisitantesTotales': '396', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'El bosque romántico', 'tipo': 'Concierto'}
# {'idacto': 105252, 'VisitantesTotales': '163', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'El sueño de volar', 'tipo': 'Conferencia'}
# {'idacto': 105418, 'VisitantesTotales': '380', 'cancelado': 0, 'formato': 'Viernes Temáticos', 'nombre': 'Tango, amor desconsolado', 'tipo': 'Concierto'}
# {'idacto': 105038, 'VisitantesTotales': '396', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Nueva York, cabaré americano', 'tipo': 'Concierto'}
# {'idacto': 105072, 'VisitantesTotales': '396', 'cancelado': 0, 'formato': 'Viernes Temáticos', 'nombre': 'Tango, amor desconsolado', 'tipo': 'Concierto'}
# {'idacto': 105084, 'VisitantesTotales': '359', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Sào y Cosima Soulez Larivière y Bruno Philippe', 'tipo': 'Concierto'}
# {'idacto': 105371, 'VisitantesTotales': '55', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': '<em>Wara Wara</em>', 'tipo': 'Conferencia'}
# {'idacto': 105383, 'VisitantesTotales': '46', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': '<em>La montaña sagrada</em>', 'tipo': 'Conferencia'}
# {'idacto': 105085, 'VisitantesTotales': '282', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Sào y Cosima Soulez Larivière y Bruno Philippe', 'tipo': 'Concierto'}
# {'idacto': 105348, 'VisitantesTotales': '195', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Astérix y otros personajes de René Goscinny', 'tipo': 'Conferencia'}
# {'idacto': 105042, 'VisitantesTotales': '335', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'Folclore, vanguardia y tonalidad', 'tipo': 'Concierto'}
# {'idacto': 105293, 'VisitantesTotales': '387', 'cancelado': 0, 'formato': 'Diálogos cosmopolitas', 'nombre': 'Mary Beard', 'tipo': 'Conferencia'}
# {'idacto': 105039, 'VisitantesTotales': '396', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': '<em>Ceci n´est pas une femme</em>', 'tipo': 'Concierto'}
# {'idacto': 105082, 'VisitantesTotales': '260', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Carolina Santiago', 'tipo': 'Concierto'}
# {'idacto': 105275, 'VisitantesTotales': '277', 'cancelado': 0, 'formato': 'La cuestión palpitante', 'nombre': 'El arte: entre el valor y el precio', 'tipo': 'Conferencia'}
# {'idacto': 105083, 'VisitantesTotales': '228', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Carolina Santiago', 'tipo': 'Concierto'}
# {'idacto': 105269, 'VisitantesTotales': '306', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Figuras divinas. Lecturas y comprensión del cuerpo humano en el Egipto antiguo', 'tipo': 'Conferencia'}
# {'idacto': 105043, 'VisitantesTotales': '344', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'El legado chopiniano', 'tipo': 'Concierto'}
# {'idacto': 105270, 'VisitantesTotales': '306', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La invención del cuerpo en la Grecia antigua', 'tipo': 'Conferencia'}
# {'idacto': 105255, 'VisitantesTotales': '394', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>El código criminal</em> (1930) de Howard Hawks', 'tipo': 'Conferencia'}
# {'idacto': 105256, 'VisitantesTotales': '354', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>El código criminal</em> (1930) de Howard Hawks', 'tipo': 'Conferencia'}
# {'idacto': 105040, 'VisitantesTotales': '349', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': '<em>Kabarett Berlin</em>', 'tipo': 'Concierto'}
# {'idacto': 105088, 'VisitantesTotales': '281', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Rachel Fenlon', 'tipo': 'Concierto'}
# {'idacto': 105304, 'VisitantesTotales': '69', 'cancelado': 0, 'formato': 'Memorias de la Fundación', 'nombre': 'Carlos Muñoz de Pablos ', 'tipo': 'Conferencia'}
# {'idacto': 105089, 'VisitantesTotales': '281', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Rachel Fenlon', 'tipo': 'Concierto'}
# {'idacto': 105271, 'VisitantesTotales': '242', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Los iberos y la imagen de la figura humana', 'tipo': 'Conferencia'}
# {'idacto': 105044, 'VisitantesTotales': '358', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'Otoño de Varsovia', 'tipo': 'Concierto'}
# {'idacto': 105272, 'VisitantesTotales': '299', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La figura humana en el arte romano. El poder de la imagen.', 'tipo': 'Conferencia'}
# {'idacto': 105385, 'VisitantesTotales': '394', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': 'Preestreno de <em>Cristina Garc&iacute;a Rodero: la mirada oculta</em>', 'tipo': 'Conferencia'}
# {'idacto': 105041, 'VisitantesTotales': '354', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Del cabaré al auditorio', 'tipo': 'Concierto'}
# {'idacto': 105090, 'VisitantesTotales': '284', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Marta Puig', 'tipo': 'Concierto'}
# {'idacto': 105364, 'VisitantesTotales': '191', 'cancelado': 0, 'formato': 'La exposición explicada', 'nombre': 'Acerca de la exposici&oacute;n <em>Antes de Am&eacute;rica. Fuentes originarias en la cultura moderna</em>', 'tipo': 'Conferencia'}
# {'idacto': 105091, 'VisitantesTotales': '272', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Marta Puig', 'tipo': 'Concierto'}
# {'idacto': 105362, 'VisitantesTotales': '299', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'De frontera a imperio', 'tipo': 'Conferencia'}
# {'idacto': 105045, 'VisitantesTotales': '303', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'Polskie Requiem', 'tipo': 'Concierto'}
# {'idacto': 105363, 'VisitantesTotales': '141', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'De imperio a nación', 'tipo': 'Conferencia'}
# {'idacto': 105257, 'VisitantesTotales': '371', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>Hampa dorada</em> (1931) de Mervyn LeRoy', 'tipo': 'Conferencia'}
# {'idacto': 105258, 'VisitantesTotales': '343', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>Hampa dorada</em> (1931) de Mervyn LeRoy', 'tipo': 'Conferencia'}
# {'idacto': 105047, 'VisitantesTotales': '283', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Escuchar la naturaleza', 'tipo': 'Concierto'}
# {'idacto': 105092, 'VisitantesTotales': '334', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Ismael Campanero', 'tipo': 'Concierto'}
# {'idacto': 105291, 'VisitantesTotales': '130', 'cancelado': 0, 'formato': 'La cuestión palpitante', 'nombre': 'La financiación de la cultura', 'tipo': 'Conferencia'}
# {'idacto': 105093, 'VisitantesTotales': '282', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Ismael Campanero', 'tipo': 'Concierto'}
# {'idacto': 105289, 'VisitantesTotales': '396', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Vida de Maquiavelo: el contexto', 'tipo': 'Conferencia'}
# {'idacto': 105046, 'VisitantesTotales': '277', 'cancelado': 0, 'formato': 'Aula de (Re)estrenos', 'nombre': 'Aula de (Re)estrenos (123). Música electrónica vs. instrumental: diálogos de timbres', 'tipo': 'Concierto'}
# {'idacto': 105290, 'VisitantesTotales': '333', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La teoría política de Maquiavelo', 'tipo': 'Conferencia'}
# {'idacto': 105349, 'VisitantesTotales': '39', 'cancelado': 0, 'formato': 'Memorias de la Fundación', 'nombre': 'Félix Vidal Costa', 'tipo': 'Conferencia'}
# {'idacto': 105323, 'VisitantesTotales': '287', 'cancelado': 0, 'formato': 'Teatro Musical de Cámara', 'nombre': '<em>La muerte y el industrial</em> de Jorge Fern&aacute;ndez Guerra', 'tipo': 'Concierto'}
# {'idacto': 105324, 'VisitantesTotales': '271', 'cancelado': 0, 'formato': 'Teatro Musical de Cámara', 'nombre': '<em>La muerte y el industrial</em> de Jorge Fern&aacute;ndez Guerra', 'tipo': 'Concierto'}
# {'idacto': 105374, 'VisitantesTotales': '88', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': '<em>¡Que Viva México!</em>', 'tipo': 'Conferencia'}
# {'idacto': 105379, 'VisitantesTotales': '33', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': '<em>Raíces</em>', 'tipo': 'Conferencia'}
# {'idacto': 105439, 'VisitantesTotales': '0', 'cancelado': 0, 'formato': 'La Biblioteca invita', 'nombre': '<p>La recuperaci&oacute;n de un ballet de la Edad de Plata: el caso de La Argentina</p>', 'tipo': 'Conferencia'}
# {'idacto': 105406, 'VisitantesTotales': '379', 'cancelado': 0, 'formato': 'Teatro Musical de Cámara', 'nombre': '<em>La Argentina en Par&iacute;s</em>, ballets de &Oacute;scar Espl&aacute; y Ernesto Halffter', 'tipo': 'Concierto'}
# {'idacto': 105317, 'VisitantesTotales': '294', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La batalla del Delta: soldados&nbsp;y marinos de Rams&eacute;s III frente a los Pueblos del Mar', 'tipo': 'Conferencia'}
# {'idacto': 105407, 'VisitantesTotales': '384', 'cancelado': 0, 'formato': 'Teatro Musical de Cámara', 'nombre': 'La Argentina en París', 'tipo': 'Concierto'}
# {'idacto': 105318, 'VisitantesTotales': '301', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La batalla de Salamina (480 a. C.): remos y espolones contra el Gran Rey persa', 'tipo': 'Conferencia'}
# {'idacto': 105408, 'VisitantesTotales': '382', 'cancelado': 0, 'formato': 'Teatro Musical de Cámara', 'nombre': 'La Argentina en París', 'tipo': 'Concierto'}
# {'idacto': 105409, 'VisitantesTotales': '387', 'cancelado': 0, 'formato': 'Teatro Musical de Cámara', 'nombre': 'La Argentina en París', 'tipo': 'Concierto'}
# {'idacto': 105410, 'VisitantesTotales': '383', 'cancelado': 0, 'formato': 'Teatro Musical de Cámara', 'nombre': 'La Argentina en París', 'tipo': 'Concierto'}
# {'idacto': 105411, 'VisitantesTotales': '387', 'cancelado': 0, 'formato': 'Teatro Musical de Cámara', 'nombre': 'La Argentina en París', 'tipo': 'Concierto'}
# {'idacto': 105431, 'VisitantesTotales': '163', 'cancelado': 0, 'formato': 'La cuestión palpitante', 'nombre': 'Viejos y nuevos BRICS', 'tipo': 'Conferencia'}
# {'idacto': 105319, 'VisitantesTotales': '299', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'El desastre naval cartagin&eacute;s en las islas Egadas (241 a. C.) y la moderna arqueolog&iacute;a subacu&aacute;tica', 'tipo': 'Conferencia'}
# {'idacto': 105190, 'VisitantesTotales': '0', 'cancelado': 1, 'formato': 'Ciclos de Miércoles', 'nombre': 'Bartók en España', 'tipo': 'Concierto'}
# {'idacto': 105320, 'VisitantesTotales': '327', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Actium: Octavio contra Marco Antonio y Cleopatra', 'tipo': 'Conferencia'}
# {'idacto': 105074, 'VisitantesTotales': '386', 'cancelado': 0, 'formato': 'Viernes Temáticos', 'nombre': 'Amor melanc&oacute;lico: <em>chanson </em>y fado', 'tipo': 'Concierto'}
# {'idacto': 105075, 'VisitantesTotales': '390', 'cancelado': 0, 'formato': 'Viernes Temáticos', 'nombre': 'Amor melanc&oacute;lico: <em>chanson </em>y fado', 'tipo': 'Concierto'}
# {'idacto': 105193, 'VisitantesTotales': '322', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Arpa sacra y profana', 'tipo': 'Concierto'}
# {'idacto': 105212, 'VisitantesTotales': '360', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Trío Kalon', 'tipo': 'Concierto'}
# {'idacto': 105435, 'VisitantesTotales': '28', 'cancelado': 0, 'formato': 'Memorias de la Fundación', 'nombre': 'Vicente Salas Fum&aacute;s', 'tipo': 'Conferencia'}
# {'idacto': 105211, 'VisitantesTotales': '282', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Trío Kalon', 'tipo': 'Concierto'}
# {'idacto': 105321, 'VisitantesTotales': '284', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La batalla naval de La Rochela (1372)', 'tipo': 'Conferencia'}
# {'idacto': 105189, 'VisitantesTotales': '394', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'El Bartók coral, en contexto', 'tipo': 'Concierto'}
# {'idacto': 105322, 'VisitantesTotales': '396', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La batalla de Lepanto', 'tipo': 'Conferencia'}
# {'idacto': 105259, 'VisitantesTotales': '393', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>El enemigo p&uacute;blico</em>&nbsp;(1931) de William Wellman ', 'tipo': 'Conferencia'}
# {'idacto': 105260, 'VisitantesTotales': '383', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>El enemigo p&uacute;blico</em>&nbsp;(1931) de William Wellman ', 'tipo': 'Conferencia'}
# {'idacto': 105194, 'VisitantesTotales': '342', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'El arpa de Ariadna', 'tipo': 'Concierto'}
# {'idacto': 105213, 'VisitantesTotales': '333', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Trío Schola', 'tipo': 'Concierto'}
# {'idacto': 105375, 'VisitantesTotales': '58', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': '<em>El signo de la muerte</em>', 'tipo': 'Conferencia'}
# {'idacto': 105382, 'VisitantesTotales': '47', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': '<em>El secreto de los incas</em>', 'tipo': 'Conferencia'}
# {'idacto': 105214, 'VisitantesTotales': '282', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Trío Schola', 'tipo': 'Concierto'}
# {'idacto': 105294, 'VisitantesTotales': '334', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'John Ford: poeta y comediante', 'tipo': 'Conferencia'}
# {'idacto': 105191, 'VisitantesTotales': '337', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'El Bartók folclorista', 'tipo': 'Concierto'}
# {'idacto': 105295, 'VisitantesTotales': '375', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': '<p>El cine seg&uacute;n John Ford</p>', 'tipo': 'Conferencia'}
# {'idacto': 105195, 'VisitantesTotales': '312', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'El arpa, un instrumento femenino', 'tipo': 'Concierto'}
# {'idacto': 105215, 'VisitantesTotales': '318', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Dúo Éire', 'tipo': 'Concierto'}
# {'idacto': 105380, 'VisitantesTotales': '66', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': '<em>Raíces</em>', 'tipo': 'Conferencia'}
# {'idacto': 105376, 'VisitantesTotales': '33', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': '<em>El signo de la muerte</em> ', 'tipo': 'Conferencia'}
# {'idacto': 105216, 'VisitantesTotales': '271', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Dúo Éire', 'tipo': 'Concierto'}
# {'idacto': 105365, 'VisitantesTotales': '382', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Francisco Giner de los R&iacute;os: el primer espa&ntilde;ol moderno', 'tipo': 'Conferencia'}
# {'idacto': 105192, 'VisitantesTotales': '301', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'La cosmología pianística de Bartók', 'tipo': 'Concierto'}
# {'idacto': 105366, 'VisitantesTotales': '259', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'El legado de Giner de los R&iacute;os', 'tipo': 'Conferencia'}
# {'idacto': 105265, 'VisitantesTotales': '346', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>Dinero f&aacute;cil</em> (1931) de Alfred E. Green', 'tipo': 'Conferencia'}
# {'idacto': 105266, 'VisitantesTotales': '358', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>Dinero f&aacute;cil</em> (1931) de Alfred E. Green', 'tipo': 'Conferencia'}
# {'idacto': 105196, 'VisitantesTotales': '305', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'El arpa conquista la esfera pública', 'tipo': 'Concierto'}
# {'idacto': 105217, 'VisitantesTotales': '333', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Anacronía', 'tipo': 'Concierto'}
# {'idacto': 105548, 'VisitantesTotales': '0', 'cancelado': 0, 'formato': 'La Biblioteca invita', 'nombre': '<p>El podcast La Biblioteca de Julio estrena temporada</p>', 'tipo': 'Conferencia'}
# {'idacto': 105438, 'VisitantesTotales': '22', 'cancelado': 0, 'formato': 'Memorias de la Fundación', 'nombre': 'Antonio C&oacute;rdoba Barba', 'tipo': 'Conferencia'}
# {'idacto': 105218, 'VisitantesTotales': '282', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Anacronía', 'tipo': 'Concierto'}
# {'idacto': 105387, 'VisitantesTotales': '394', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Los celtas en Europa: poblamiento y cultura', 'tipo': 'Conferencia'}
# {'idacto': 105197, 'VisitantesTotales': '277', 'cancelado': 0, 'formato': 'Aula de (Re)estrenos', 'nombre': '124. Proyecto Conrado: integral de sus cuartetos (IV)', 'tipo': 'Concierto'}
# {'idacto': 105388, 'VisitantesTotales': '275', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La historia genética de los celtas en Europa', 'tipo': 'Conferencia'}
# {'idacto': 105414, 'VisitantesTotales': '332', 'cancelado': 0, 'formato': 'Viernes Temáticos', 'nombre': 'Amor místico', 'tipo': 'Concierto'}
# {'idacto': 105415, 'VisitantesTotales': '304', 'cancelado': 0, 'formato': 'Viernes Temáticos', 'nombre': 'Amor místico', 'tipo': 'Concierto'}
# {'idacto': 105198, 'VisitantesTotales': '303', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Contra el olvido', 'tipo': 'Concierto'}
# {'idacto': 105219, 'VisitantesTotales': '335', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Dúo Da Vinci de Google', 'tipo': 'Concierto'}
# {'idacto': 105461, 'VisitantesTotales': '132', 'cancelado': 0, 'formato': 'La cuestión palpitante', 'nombre': 'El desempleo en Espa&ntilde;a', 'tipo': 'Conferencia'}
# {'idacto': 105220, 'VisitantesTotales': '282', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Dúo Da Vinci de Google', 'tipo': 'Concierto'}
# {'idacto': 105389, 'VisitantesTotales': '297', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Las lenguas de los celtas', 'tipo': 'Conferencia'}
# {'idacto': 105202, 'VisitantesTotales': '338', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'Isabel II, pianista ', 'tipo': 'Concierto'}
# {'idacto': 105390, 'VisitantesTotales': '285', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Druidismo, cosmolog&iacute;a y calendario en el mundo c&eacute;ltico', 'tipo': 'Conferencia'}
# {'idacto': 105261, 'VisitantesTotales': '388', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>Las calles de la ciudad</em> (1931) de Rouben Mamoulian ', 'tipo': 'Conferencia'}
# {'idacto': 105262, 'VisitantesTotales': '388', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>Las calles de la ciudad</em> (1931) de Rouben Mamoulian ', 'tipo': 'Conferencia'}
# {'idacto': 105199, 'VisitantesTotales': '396', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Fado saudade', 'tipo': 'Concierto'}
# {'idacto': 105221, 'VisitantesTotales': '319', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'La Camerata Chromatica', 'tipo': 'Concierto'}
# {'idacto': 105545, 'VisitantesTotales': '31', 'cancelado': 0, 'formato': 'Memorias de la Fundación', 'nombre': 'Estella Matutes Juan', 'tipo': 'Conferencia'}
# {'idacto': 105222, 'VisitantesTotales': '282', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'La Camerata Chromatica', 'tipo': 'Concierto'}
# {'idacto': 105391, 'VisitantesTotales': '268', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'En busca de las religiones de la Céltica antigua', 'tipo': 'Conferencia'}
# {'idacto': 105203, 'VisitantesTotales': '395', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'Danzas para dos reinas: María Luisa de Saboya e Isabel de Farnesio', 'tipo': 'Concierto'}
# {'idacto': 105392, 'VisitantesTotales': '260', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'El celtismo popular: mitos, leyendas y nuevos medios de comunicación', 'tipo': 'Conferencia'}
# {'idacto': 105200, 'VisitantesTotales': '322', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Un mar de memorias', 'tipo': 'Concierto'}
# {'idacto': 105223, 'VisitantesTotales': '350', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Cuarteto Erinys', 'tipo': 'Concierto'}
# {'idacto': 105384, 'VisitantesTotales': '73', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': '<em>La montaña sagrada</em>', 'tipo': 'Conferencia'}
# {'idacto': 105378, 'VisitantesTotales': '30', 'cancelado': 0, 'formato': 'Cine y Arte', 'nombre': '<em>Deseada</em>', 'tipo': 'Conferencia'}
# {'idacto': 105224, 'VisitantesTotales': '282', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Cuarteto Erinys', 'tipo': 'Concierto'}
# {'idacto': 105424, 'VisitantesTotales': '394', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La guerra de Troya y los hititas', 'tipo': 'Conferencia'}
# {'idacto': 105204, 'VisitantesTotales': '353', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'El Códice de las Huelgas', 'tipo': 'Concierto'}
# {'idacto': 105428, 'VisitantesTotales': '329', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La guerra de Troya: arqueolog&iacute;a, historia e iconograf&iacute;a', 'tipo': 'Conferencia'}
# {'idacto': 105416, 'VisitantesTotales': '305', 'cancelado': 0, 'formato': 'Viernes Temáticos', 'nombre': 'Los trovadores y el amor cortés', 'tipo': 'Concierto'}
# {'idacto': 105417, 'VisitantesTotales': '288', 'cancelado': 0, 'formato': 'Viernes Temáticos', 'nombre': 'Los trovadores y el amor cortés', 'tipo': 'Concierto'}
# {'idacto': 105201, 'VisitantesTotales': '313', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Lachrimae', 'tipo': 'Concierto'}
# {'idacto': 105225, 'VisitantesTotales': '317', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Quinteto Cierzo', 'tipo': 'Concierto'}
# {'idacto': 105226, 'VisitantesTotales': '272', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Quinteto Cierzo', 'tipo': 'Concierto'}
# {'idacto': 105429, 'VisitantesTotales': '396', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La <em>Il&iacute;ada</em> y la guerra de Troya', 'tipo': 'Conferencia'}
# {'idacto': 105206, 'VisitantesTotales': '296', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'NA', 'tipo': 'Concierto'}
# {'idacto': 105430, 'VisitantesTotales': '324', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Antes y despu&eacute;s de la <em>Il&iacute;ada</em>: el Ciclo &eacute;pico', 'tipo': 'Conferencia'}
# {'idacto': 105351, 'VisitantesTotales': '0', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'Weinberg a debate', 'tipo': 'Concierto'}
# {'idacto': 105207, 'VisitantesTotales': '244', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'NA', 'tipo': 'Concierto'}
# {'idacto': 105209, 'VisitantesTotales': '232', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'NA', 'tipo': 'Concierto'}
# {'idacto': 105208, 'VisitantesTotales': '249', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'NA', 'tipo': 'Concierto'}
# {'idacto': 105210, 'VisitantesTotales': '279', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'NA', 'tipo': 'Concierto'}
# {'idacto': 105571, 'VisitantesTotales': '0', 'cancelado': 0, 'formato': 'La Biblioteca invita', 'nombre': '<p>Y despu&eacute;s de <em>Antes de Am&eacute;rica</em>, &iquest;qu&eacute;?</p>', 'tipo': 'Conferencia'}
# {'idacto': 105432, 'VisitantesTotales': '202', 'cancelado': 0, 'formato': 'La cuestión palpitante', 'nombre': 'El español, su presente y futuro como lengua internacional', 'tipo': 'Conferencia'}
# {'idacto': 105367, 'VisitantesTotales': '156', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Los idus de mayo: el París de Deleuze', 'tipo': 'Conferencia'}
# {'idacto': 105205, 'VisitantesTotales': '325', 'cancelado': 0, 'formato': 'Concierto Extraordinario', 'nombre': 'Tríos y retratos: Castel y Goya', 'tipo': 'Concierto'}
# {'idacto': 105368, 'VisitantesTotales': '232', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Deleuze como pensador: planos de fuga', 'tipo': 'Conferencia'}
# {'idacto': 105263, 'VisitantesTotales': '394', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>Scarface, el terror del hampa</em> (1932) de Howard Hawks ', 'tipo': 'Conferencia'}
# {'idacto': 105264, 'VisitantesTotales': '384', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>Scarface, el terror del hampa</em> (1932) de Howard Hawks ', 'tipo': 'Conferencia'}
# {'idacto': 105557, 'VisitantesTotales': '350', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Simone de Beauvoir: su vida, su tiempo', 'tipo': 'Conferencia'}
# {'idacto': 105483, 'VisitantesTotales': '395', 'cancelado': 0, 'formato': 'Melodramas', 'nombre': 'Cabaré Pierrot', 'tipo': 'Concierto'}
# {'idacto': 105558, 'VisitantesTotales': '297', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'El feminismo que nació con Simone de Beauvoir', 'tipo': 'Conferencia'}
# {'idacto': 105484, 'VisitantesTotales': '342', 'cancelado': 0, 'formato': 'Melodramas', 'nombre': 'Cabaré Pierrot', 'tipo': 'Concierto'}
# {'idacto': 105485, 'VisitantesTotales': '376', 'cancelado': 0, 'formato': 'Melodramas', 'nombre': 'Cabaré Pierrot', 'tipo': 'Concierto'}
# {'idacto': 105574, 'VisitantesTotales': '20', 'cancelado': 0, 'formato': 'Memorias de la Fundación', 'nombre': 'Emilio Casares', 'tipo': 'Conferencia'}
# {'idacto': 105559, 'VisitantesTotales': '377', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': '<em>El Mes&iacute;as</em> de Handel', 'tipo': 'Conferencia'}
# {'idacto': 105305, 'VisitantesTotales': '342', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'NA', 'tipo': 'Concierto'}
# {'idacto': 105560, 'VisitantesTotales': '334', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La Misa en Si menor de Bach: final de trayecto', 'tipo': 'Conferencia'}
# {'idacto': 105354, 'VisitantesTotales': '395', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Musicales en <em>big band</em>', 'tipo': 'Concierto'}
# {'idacto': 105227, 'VisitantesTotales': '334', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Cuarteto Synthèse', 'tipo': 'Concierto'}
# {'idacto': 105578, 'VisitantesTotales': '272', 'cancelado': 0, 'formato': 'La cuestión palpitante', 'nombre': 'El sueño: importancia y trastornos', 'tipo': 'Conferencia'}
# {'idacto': 105228, 'VisitantesTotales': '277', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Cuarteto Synthèse', 'tipo': 'Concierto'}
# {'idacto': 105561, 'VisitantesTotales': '375', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Paradojas del <em>R&eacute;quiem</em> de Mozart: la &oacute;pera en el templo', 'tipo': 'Conferencia'}
# {'idacto': 105306, 'VisitantesTotales': '310', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'NA', 'tipo': 'Concierto'}
# {'idacto': 105562, 'VisitantesTotales': '388', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La <em>Novena</em> de Beethoven: el abrazo que no cesa', 'tipo': 'Conferencia'}
# {'idacto': 105419, 'VisitantesTotales': '280', 'cancelado': 0, 'formato': 'Viernes Temáticos', 'nombre': 'Amor mitológico: Adonis y Venus', 'tipo': 'Concierto'}
# {'idacto': 105420, 'VisitantesTotales': '269', 'cancelado': 0, 'formato': 'Viernes Temáticos', 'nombre': 'Amor mitológico: Adonis y Venus', 'tipo': 'Concierto'}
# {'idacto': 105355, 'VisitantesTotales': '345', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Un armonicista en Broadway', 'tipo': 'Concierto'}
# {'idacto': 105229, 'VisitantesTotales': '333', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Anna Urpina', 'tipo': 'Concierto'}
# {'idacto': 105230, 'VisitantesTotales': '280', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Anna Urpina', 'tipo': 'Concierto'}
# {'idacto': 105581, 'VisitantesTotales': '313', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Jorge Juan y la expedición al Ecuador para esclarecer la forma de la Tierra', 'tipo': 'Conferencia'}
# {'idacto': 105307, 'VisitantesTotales': '323', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'NA', 'tipo': 'Concierto'}
# {'idacto': 105582, 'VisitantesTotales': '305', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'José Celestino Mutis: el héroe de las mil caras y la flora imaginaria', 'tipo': 'Conferencia'}
# {'idacto': 105356, 'VisitantesTotales': '323', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'De Gershwin a Cole Porter', 'tipo': 'Concierto'}
# {'idacto': 105231, 'VisitantesTotales': '294', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Dennis Orellana, Sofía Gutiérrez-Tobar y Julen Jiménez', 'tipo': 'Concierto'}
# {'idacto': 105232, 'VisitantesTotales': '249', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Dennis Orellana, Sofía Gutiérrez-Tobar y Julen Jiménez', 'tipo': 'Concierto'}
# {'idacto': 105583, 'VisitantesTotales': '306', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La Real Expedición de la Vacuna vista por un virólogo', 'tipo': 'Conferencia'}
# {'idacto': 105357, 'VisitantesTotales': '396', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'La época dorada del claqué', 'tipo': 'Concierto'}
# {'idacto': 105233, 'VisitantesTotales': '264', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Maëlys Robinne', 'tipo': 'Concierto'}
# {'idacto': 105580, 'VisitantesTotales': '43', 'cancelado': 0, 'formato': 'Memorias de la Fundación', 'nombre': 'Álvaro Cuervo', 'tipo': 'Conferencia'}
# {'idacto': 105234, 'VisitantesTotales': '252', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Maëlys Robinne', 'tipo': 'Concierto'}
# {'idacto': 105590, 'VisitantesTotales': '294', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Fernando Zóbel, la pintura y la historia', 'tipo': 'Conferencia'}
# {'idacto': 105308, 'VisitantesTotales': '287', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'NA', 'tipo': 'Concierto'}
# {'idacto': 105591, 'VisitantesTotales': '236', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La geografía de Fernando Zóbel', 'tipo': 'Conferencia'}
# {'idacto': 105575, 'VisitantesTotales': '242', 'cancelado': 0, 'formato': 'Diálogos cosmopolitas', 'nombre': 'David Chipperfield', 'tipo': 'Conferencia'}
# {'idacto': 105543, 'VisitantesTotales': '322', 'cancelado': 0, 'formato': 'Acto inaugural', 'nombre': 'Inauguraci&oacute;n de la exposición «El peque&ntilde;o museo m&aacute;s bello del mundo»', 'tipo': 'Concierto'}
# {'idacto': 105492, 'VisitantesTotales': '396', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Melodías ancestrales sacuden al mundo', 'tipo': 'Concierto'}
# {'idacto': 105235, 'VisitantesTotales': '288', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Cuartetos de violonchelos del RCSMM', 'tipo': 'Concierto'}
# {'idacto': 105572, 'VisitantesTotales': '218', 'cancelado': 0, 'formato': 'La cuestión palpitante', 'nombre': 'La polarizaci&oacute;n pol&iacute;tica', 'tipo': 'Conferencia'}
# {'idacto': 105236, 'VisitantesTotales': '280', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Cuartetos de violonchelos del RCSMM', 'tipo': 'Concierto'}
# {'idacto': 105584, 'VisitantesTotales': '350', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Los fenicios, entre el misterio y la realidad', 'tipo': 'Conferencia'}
# {'idacto': 105309, 'VisitantesTotales': '396', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'Lorca: in memoriam', 'tipo': 'Concierto'}
# {'idacto': 105585, 'VisitantesTotales': '285', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Novedades arqueológicas sobre el mundo fenicio', 'tipo': 'Conferencia'}
# {'idacto': 105421, 'VisitantesTotales': '393', 'cancelado': 0, 'formato': 'Viernes Temáticos', 'nombre': 'Boleros, penas de amor', 'tipo': 'Concierto'}
# {'idacto': 105422, 'VisitantesTotales': '389', 'cancelado': 0, 'formato': 'Viernes Temáticos', 'nombre': 'Boleros, penas de amor', 'tipo': 'Concierto'}
# {'idacto': 105493, 'VisitantesTotales': '384', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Folk tejido con el violín', 'tipo': 'Concierto'}
# {'idacto': 105237, 'VisitantesTotales': '284', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Roman Borisov', 'tipo': 'Concierto'}
# {'idacto': 105603, 'VisitantesTotales': '207', 'cancelado': 0, 'formato': 'La exposición explicada', 'nombre': 'Acerca de la exposici&oacute;n <em>&laquo;El peque&ntilde;o museo m&aacute;s bello del mundo&raquo;</em>', 'tipo': 'Conferencia'}
# {'idacto': 105238, 'VisitantesTotales': '281', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Roman Borisov', 'tipo': 'Concierto'}
# {'idacto': 105586, 'VisitantesTotales': '279', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'La religi&oacute;n fenicia', 'tipo': 'Conferencia'}
# {'idacto': 105310, 'VisitantesTotales': '353', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'Lorca en forma de canciones', 'tipo': 'Concierto'}
# {'idacto': 105587, 'VisitantesTotales': '266', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Una fama bien merecida. Las actividades productivas de los fenicios', 'tipo': 'Conferencia'}
# {'idacto': 105267, 'VisitantesTotales': '389', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>El enemigo p&uacute;blico n&uacute;mero 1</em> (1934) de W. S. Van Dyke ', 'tipo': 'Conferencia'}
# {'idacto': 105268, 'VisitantesTotales': '354', 'cancelado': 0, 'formato': 'Cine en la March', 'nombre': '<em>El enemigo p&uacute;blico n&uacute;mero 1</em> (1934) de W. S. Van Dyke ', 'tipo': 'Conferencia'}
# {'idacto': 105494, 'VisitantesTotales': '385', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Esencia viva: folk en otra piel', 'tipo': 'Concierto'}
# {'idacto': 105239, 'VisitantesTotales': '269', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Cuarteto Chaos', 'tipo': 'Concierto'}
# {'idacto': 105240, 'VisitantesTotales': '275', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Cuarteto Chaos', 'tipo': 'Concierto'}
# {'idacto': 105588, 'VisitantesTotales': '255', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Los fenicios, su escritura y sus escritos', 'tipo': 'Conferencia'}
# {'idacto': 105311, 'VisitantesTotales': '392', 'cancelado': 0, 'formato': 'Ciclos de Miércoles', 'nombre': 'Poemas lorquianos del cante jondo', 'tipo': 'Concierto'}
# {'idacto': 105589, 'VisitantesTotales': '259', 'cancelado': 0, 'formato': 'Ciclos de conferencias', 'nombre': 'Del Mediterráneo al Atlántico: la expansión fenicia', 'tipo': 'Conferencia'}
# {'idacto': 105617, 'VisitantesTotales': '0', 'cancelado': 0, 'formato': 'La Biblioteca invita', 'nombre': '<p>Las estancias del asombro</p>', 'tipo': 'Conferencia'}
# {'idacto': 105314, 'VisitantesTotales': '331', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Danza española: folclore, flamenco y sentimiento', 'tipo': 'Concierto'}
# {'idacto': 105048, 'VisitantesTotales': '390', 'cancelado': 0, 'formato': 'Conciertos del Sábado', 'nombre': 'Danza española: folclore, flamenco y sentimiento', 'tipo': 'Concierto'}
# {'idacto': 105287, 'VisitantesTotales': '249', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Álvaro Toscano', 'tipo': 'Concierto'}
# {'idacto': 105288, 'VisitantesTotales': '261', 'cancelado': 0, 'formato': 'Jóvenes intérpretes', 'nombre': 'Álvaro Toscano', 'tipo': 'Concierto'}
# {'idacto': 105313, 'VisitantesTotales': '390', 'cancelado': 0, 'formato': 'Concierto Extraordinario', 'nombre': 'La emoción de las voces. Clausura de la temporada de conciertos 2023-2024', 'tipo': 'Concierto'}
# {'idacto': 105644, 'VisitantesTotales': '0', 'cancelado': 0, 'formato': 'Actos especiales', 'nombre': 'Programación especial de Radio Clásica desde la Fundación Juan March', 'tipo': 'Concierto'}
# {'idacto': 105646, 'VisitantesTotales': '0', 'cancelado': 0, 'formato': 'Actos especiales', 'nombre': 'Programación especial de Radio Clásica desde la Fundación Juan March', 'tipo': 'Concierto'}
# {'idacto': 105645, 'VisitantesTotales': '0', 'cancelado': 0, 'formato': 'Actos especiales', 'nombre': 'Programación especial de Radio Clásica desde la Fundación Juan March', 'tipo': 'Concierto'}
# {'idacto': 105712, 'VisitantesTotales': '325', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'La palabra en escena como un viaje a otros lugares', 'tipo': 'Conferencia'}
# {'idacto': 105741, 'VisitantesTotales': '40', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'El sabor de las palabras', 'tipo': 'Conferencia'}
# {'idacto': 105711, 'VisitantesTotales': '312', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'La palabra de la ausencia, la dicha de la soledad', 'tipo': 'Conferencia'}
# {'idacto': 105743, 'VisitantesTotales': '20', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'Biblioteca Humana', 'tipo': 'Conferencia'}
# {'idacto': 105745, 'VisitantesTotales': '10', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'Aprende a pensar y a decir el verso', 'tipo': 'Conferencia'}
# {'idacto': 105710, 'VisitantesTotales': '241', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'La palabra de la lucha, la dicha de la militancia', 'tipo': 'Conferencia'}
# {'idacto': 105740, 'VisitantesTotales': '40', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'El sabor de las palabras', 'tipo': 'Conferencia'}
# {'idacto': 105742, 'VisitantesTotales': '16', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'Biblioteca Humana', 'tipo': 'Conferencia'}
# {'idacto': 105744, 'VisitantesTotales': '4', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'Aprende a pensar y a decir el verso', 'tipo': 'Conferencia'}
# {'idacto': 105709, 'VisitantesTotales': '236', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'La palabra explicada, la dicha de la palabra viva', 'tipo': 'Conferencia'}
# {'idacto': 105738, 'VisitantesTotales': '16', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'La palabra dicha y dichosa. Actividades breves', 'tipo': 'Conferencia'}
# {'idacto': 105739, 'VisitantesTotales': '30', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'Que oy&eacute;ndolo se pueda saber todo', 'tipo': 'Conferencia'}
# {'idacto': 105707, 'VisitantesTotales': '288', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'La palabra del amor, la dicha del sentimiento', 'tipo': 'Conferencia'}
# {'idacto': 105737, 'VisitantesTotales': '20', 'cancelado': 0, 'formato': 'Festival', 'nombre': 'La palabra dicha y dichosa. Actividades breves', 'tipo': 'Conferencia'}
# {'idacto': 105708, 'VisitantesTotales': '0', 'cancelado': 0, 'formato': 'Actos especiales', 'nombre': 'Encuentros sobre ilusionismo y teatro', 'tipo': 'Conferencia'}
# {'idacto': 105303, 'VisitantesTotales': '254', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Danza española: foclore, flamenco y sentimiento [12:30]', 'tipo': 'Concierto'}
# {'idacto': 105302, 'VisitantesTotales': '238', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Danza española: folclore, flamenco y sentimiento [10:30]', 'tipo': 'Concierto'}
# {'idacto': 105301, 'VisitantesTotales': '189', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Danza española: folclore, flamenco y sentimiento [12:30]', 'tipo': 'Concierto'}
# {'idacto': 105300, 'VisitantesTotales': '270', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Danza española: folclore, flamenco y sentimiento [10:30]', 'tipo': 'Concierto'}
# {'idacto': 105339, 'VisitantesTotales': '185', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Escuchar la naturaleza [10:30]', 'tipo': 'Concierto'}
# {'idacto': 105338, 'VisitantesTotales': '207', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Escuchar la naturaleza [12:30]', 'tipo': 'Concierto'}
# {'idacto': 105337, 'VisitantesTotales': '247', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Escuchar la naturaleza [10:30]', 'tipo': 'Concierto'}
# {'idacto': 105297, 'VisitantesTotales': '275', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Escuchar la naturaleza [12:30]', 'tipo': 'Concierto'}
# {'idacto': 105296, 'VisitantesTotales': '251', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Escuchar la naturaleza [10:30]', 'tipo': 'Concierto'}
# {'idacto': 105299, 'VisitantesTotales': '276', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Danza española: folclore, flamenco y sentimiento [12:30]', 'tipo': 'Concierto'}
# {'idacto': 105298, 'VisitantesTotales': '289', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Danza española: folclore, flamenco y sentimiento [10:30]', 'tipo': 'Concierto'}
# {'idacto': 105055, 'VisitantesTotales': '252', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Escuchar la naturaleza [12:30]', 'tipo': 'Concierto'}
# {'idacto': 105054, 'VisitantesTotales': '283', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Escuchar la naturaleza [10:30]', 'tipo': 'Concierto'}
# {'idacto': 105053, 'VisitantesTotales': '252', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Escuchar la naturaleza [12:30]', 'tipo': 'Concierto'}
# {'idacto': 105052, 'VisitantesTotales': '241', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Escuchar la naturaleza [10:30]', 'tipo': 'Concierto'}
# {'idacto': 105051, 'VisitantesTotales': '282', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Danza española: folclore, flamenco y sentimiento [12:30]', 'tipo': 'Concierto'}
# {'idacto': 105050, 'VisitantesTotales': '297', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Danza española: folclore, flamenco y sentimiento [10:30]', 'tipo': 'Concierto'}
# {'idacto': 105049, 'VisitantesTotales': '240', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Danza española: folclore, flamenco y sentimiento [12:30]', 'tipo': 'Concierto'}
# {'idacto': 105031, 'VisitantesTotales': '279', 'cancelado': 0, 'formato': 'Conciertos didácticos', 'nombre': 'Danza española: folclore, flamenco y sentimiento [10:30]', 'tipo': 'Concierto'}

# %% [markdown]
# Ahora para la segunda colección

# %%
projection2 = {
    "_id" : 0,
    "idActo": 1,
    "Total_Validadas": 1,
    "fecha": 1,
    "formato": 1,
    "nombre": 1,
}

resultados2 = list(mycol2.find(query, projection2))

for x in resultados2:
    print(x)
# Out:
# {'idActo': 105353, 'fecha': datetime.datetime(2023, 9, 7, 10, 0), 'nombre': 'Presentación de la temporada de conciertos 2023-24', 'formato': 'Actos especiales'}
# {'idActo': 105063, 'fecha': datetime.datetime(2023, 9, 24, 16, 30), 'Total_Validadas': 277, 'nombre': '<em>Grilletta e Porsugnacco</em> de Johann Adolph Hasse', 'formato': 'Teatro Musical de Cámara'}
# {'idActo': 105064, 'fecha': datetime.datetime(2023, 9, 27, 16, 30), 'Total_Validadas': 277, 'nombre': 'Grilletta e Porsugnacco', 'formato': 'Teatro Musical de Cámara'}
# {'idActo': 105065, 'fecha': datetime.datetime(2023, 9, 30, 10, 0), 'Total_Validadas': 272, 'nombre': 'Grilletta e Porsugnacco', 'formato': 'Teatro Musical de Cámara'}
# {'idActo': 105066, 'fecha': datetime.datetime(2023, 10, 1, 10, 0), 'Total_Validadas': 278, 'nombre': 'Grilletta e Porsugnacco', 'formato': 'Teatro Musical de Cámara'}
# {'idActo': 105037, 'fecha': datetime.datetime(2023, 10, 4, 16, 30), 'Total_Validadas': 280, 'nombre': 'Aula de (Re)estrenos (122). Folclore y poesía: la polifonía española', 'formato': 'Aula de (Re)estrenos'}
# {'idActo': 105056, 'fecha': datetime.datetime(2023, 10, 6, 16, 30), 'Total_Validadas': 224, 'nombre': 'Inauguración de la exposición <em>Antes de América. Fuentes originarias en la cultura moderna</em>', 'formato': 'Acto inaugural'}
# {'idActo': 105032, 'fecha': datetime.datetime(2023, 10, 7, 10, 0), 'Total_Validadas': 282, 'nombre': 'América popular De tristes y tangos', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105076, 'fecha': datetime.datetime(2023, 10, 8, 10, 0), 'Total_Validadas': 282, 'nombre': 'Curtis on Tour: Sexteto de cuerda', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105077, 'fecha': datetime.datetime(2023, 10, 9, 10, 0), 'Total_Validadas': 282, 'nombre': 'Curtis on Tour: Sexteto de cuerda', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105370, 'fecha': datetime.datetime(2023, 10, 9, 14, 0), 'Total_Validadas': 0, 'nombre': 'Antes de Am&eacute;rica en la gran pantalla. Fuentes originarias y modernidad cinematogr&aacute;fica <em>Wara Wara</em>', 'formato': 'Cine y Arte'}
# {'idActo': 105381, 'fecha': datetime.datetime(2023, 10, 9, 16, 30), 'Total_Validadas': 0, 'nombre': 'Antes de Am&eacute;rica en la gran pantalla. Fuentes originarias y modernidad cinematogr&aacute;fica <em>El secreto de los incas</em>', 'formato': 'Cine y Arte'}
# {'idActo': 105278, 'fecha': datetime.datetime(2023, 10, 10, 16, 30), 'Total_Validadas': 282, 'nombre': 'Estoicismo romano Séneca', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105027, 'fecha': datetime.datetime(2023, 10, 11, 16, 30), 'Total_Validadas': 280, 'nombre': 'Imágenes del Romanticismo Ensoñación nocturna', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105070, 'fecha': datetime.datetime(2023, 10, 13, 16, 0), 'Total_Validadas': 276, 'nombre': 'Mil años de amor Cupido, amor travieso', 'formato': 'Viernes Temáticos'}
# {'idActo': 105033, 'fecha': datetime.datetime(2023, 10, 14, 10, 0), 'Total_Validadas': 282, 'nombre': 'América popular Teclados sin fronteras', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105071, 'fecha': datetime.datetime(2023, 10, 14, 16, 0), 'Total_Validadas': 274, 'nombre': 'Mil años de amor Cupido, amor travieso', 'formato': 'Viernes Temáticos'}
# {'idActo': 105086, 'fecha': datetime.datetime(2023, 10, 15, 10, 0), 'Total_Validadas': 275, 'nombre': 'Cristina Cordero y Juan Barahona', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105087, 'fecha': datetime.datetime(2023, 10, 16, 10, 0), 'Total_Validadas': 282, 'nombre': 'Cristina Cordero y Juan Barahona', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105274, 'fecha': datetime.datetime(2023, 10, 16, 16, 30), 'Total_Validadas': 174, 'nombre': 'La salud pública en Europa', 'formato': 'La cuestión palpitante'}
# {'idActo': 105279, 'fecha': datetime.datetime(2023, 10, 17, 16, 30), 'Total_Validadas': 279, 'nombre': 'Estoicismo romano Epicteto', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105028, 'fecha': datetime.datetime(2023, 10, 18, 16, 30), 'Total_Validadas': 281, 'nombre': 'Imágenes del Romanticismo La patria soñada', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105280, 'fecha': datetime.datetime(2023, 10, 19, 16, 30), 'Total_Validadas': 246, 'nombre': 'Estoicismo romano Marco Aurelio', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105253, 'fecha': datetime.datetime(2023, 10, 20, 16, 0), 'Total_Validadas': 272, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>La senda del crimen </em>(1930) de Archie Mayo', 'formato': 'Cine en la March'}
# {'idActo': 105034, 'fecha': datetime.datetime(2023, 10, 21, 10, 0), 'Total_Validadas': 282, 'nombre': 'América popular Semillas europeas en Latinoamérica', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105254, 'fecha': datetime.datetime(2023, 10, 21, 16, 0), 'Total_Validadas': 260, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>La senda del crimen </em>(1930) de Archie Mayo', 'formato': 'Cine en la March'}
# {'idActo': 105080, 'fecha': datetime.datetime(2023, 10, 22, 10, 0), 'Total_Validadas': 282, 'nombre': 'Irene Roldán', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105081, 'fecha': datetime.datetime(2023, 10, 23, 10, 0), 'Total_Validadas': 239, 'nombre': 'Irene Roldán', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105276, 'fecha': datetime.datetime(2023, 10, 23, 16, 30), 'Total_Validadas': 0, 'nombre': 'María Rosa Calvo-Manzano', 'formato': 'Memorias de la Fundación'}
# {'idActo': 105031, 'fecha': datetime.datetime(2023, 10, 24, 8, 30), 'Total_Validadas': 279, 'nombre': 'Curso 2023-24 Danza española: folclore, flamenco y sentimiento [10:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105049, 'fecha': datetime.datetime(2023, 10, 24, 10, 30), 'Total_Validadas': 240, 'nombre': 'Curso 2023-24 Danza española: folclore, flamenco y sentimiento [12:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105250, 'fecha': datetime.datetime(2023, 10, 24, 16, 30), 'Total_Validadas': 181, 'nombre': 'El vuelo: de los dinosaurios a los hermanos Wright Los dinosaurios voladores', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105029, 'fecha': datetime.datetime(2023, 10, 25, 16, 30), 'Total_Validadas': 282, 'nombre': 'Imágenes del Romanticismo El desarraigo del errabundo', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105249, 'fecha': datetime.datetime(2023, 10, 26, 16, 30), 'Total_Validadas': 148, 'nombre': 'El vuelo: de los dinosaurios a los hermanos Wright El vuelo de las primeras aves', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105035, 'fecha': datetime.datetime(2023, 10, 28, 10, 0), 'Total_Validadas': 281, 'nombre': 'América popular Nanas y habaneras latinas', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105078, 'fecha': datetime.datetime(2023, 10, 29, 11, 0), 'Total_Validadas': 281, 'nombre': 'Rafael Quirant', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105079, 'fecha': datetime.datetime(2023, 10, 30, 11, 0), 'Total_Validadas': 272, 'nombre': 'Rafael Quirant', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105373, 'fecha': datetime.datetime(2023, 10, 30, 15, 0), 'Total_Validadas': 0, 'nombre': 'Antes de Am&eacute;rica en la gran pantalla. Fuentes originarias y modernidad cinematogr&aacute;fica <em>¡Que Viva México!</em>', 'formato': 'Cine y Arte'}
# {'idActo': 105377, 'fecha': datetime.datetime(2023, 10, 30, 17, 30), 'Total_Validadas': 0, 'nombre': 'Antes de Am&eacute;rica en la gran pantalla. Fuentes originarias y modernidad cinematogr&aacute;fica <em>Deseada</em>', 'formato': 'Cine y Arte'}
# {'idActo': 105050, 'fecha': datetime.datetime(2023, 10, 31, 9, 30), 'Total_Validadas': 297, 'nombre': 'Curso 2023-24 Danza española: folclore, flamenco y sentimiento [10:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105051, 'fecha': datetime.datetime(2023, 10, 31, 11, 30), 'Total_Validadas': 282, 'nombre': 'Curso 2023-24 Danza española: folclore, flamenco y sentimiento [12:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105251, 'fecha': datetime.datetime(2023, 10, 31, 17, 30), 'Total_Validadas': 151, 'nombre': 'El vuelo: de los dinosaurios a los hermanos Wright Las aves modernas: origen y nuevas claves evolutivas', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105030, 'fecha': datetime.datetime(2023, 11, 1, 17, 30), 'Total_Validadas': 282, 'nombre': 'Imágenes del Romanticismo El bosque romántico', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105252, 'fecha': datetime.datetime(2023, 11, 2, 17, 30), 'Total_Validadas': 163, 'nombre': 'El vuelo: de los dinosaurios a los hermanos Wright El sueño de volar', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105072, 'fecha': datetime.datetime(2023, 11, 3, 17, 0), 'Total_Validadas': 282, 'nombre': 'Mil años de amor Tango, amor desconsolado', 'formato': 'Viernes Temáticos'}
# {'idActo': 105038, 'fecha': datetime.datetime(2023, 11, 4, 11, 0), 'Total_Validadas': 282, 'nombre': 'Cabaré: París-Berlín Nueva York, cabaré americano', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105418, 'fecha': datetime.datetime(2023, 11, 4, 17, 0), 'Total_Validadas': 282, 'nombre': 'Mil años de amor Tango, amor desconsolado', 'formato': 'Viernes Temáticos'}
# {'idActo': 105084, 'fecha': datetime.datetime(2023, 11, 5, 11, 0), 'Total_Validadas': 282, 'nombre': 'Sào y Cosima Soulez Larivière y Bruno Philippe', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105085, 'fecha': datetime.datetime(2023, 11, 6, 11, 0), 'Total_Validadas': 282, 'nombre': 'Sào y Cosima Soulez Larivière y Bruno Philippe', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105383, 'fecha': datetime.datetime(2023, 11, 6, 15, 0), 'nombre': 'Antes de Am&eacute;rica en la gran pantalla. Fuentes originarias y modernidad cinematogr&aacute;fica <em>La montaña sagrada</em>', 'formato': 'Cine y Arte'}
# {'idActo': 105371, 'fecha': datetime.datetime(2023, 11, 6, 17, 30), 'nombre': 'Antes de Am&eacute;rica en la gran pantalla. Fuentes originarias y modernidad cinematogr&aacute;fica <em>Wara Wara</em>', 'formato': 'Cine y Arte'}
# {'idActo': 105052, 'fecha': datetime.datetime(2023, 11, 7, 9, 30), 'Total_Validadas': 241, 'nombre': 'Curso 2023-24 Escuchar la naturaleza [10:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105053, 'fecha': datetime.datetime(2023, 11, 7, 11, 30), 'Total_Validadas': 252, 'nombre': 'Curso 2023-24 Escuchar la naturaleza [12:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105348, 'fecha': datetime.datetime(2023, 11, 7, 17, 30), 'Total_Validadas': 195, 'nombre': 'Astérix y otros personajes de René Goscinny', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105042, 'fecha': datetime.datetime(2023, 11, 8, 17, 30), 'Total_Validadas': 282, 'nombre': 'Un siglo de música polaca Folclore, vanguardia y tonalidad', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105293, 'fecha': datetime.datetime(2023, 11, 10, 17, 30), 'Total_Validadas': 282, 'nombre': 'Mary Beard', 'formato': 'Diálogos cosmopolitas'}
# {'idActo': 105039, 'fecha': datetime.datetime(2023, 11, 11, 11, 0), 'Total_Validadas': 282, 'nombre': 'Cabaré: París-Berlín <em>Ceci n´est pas une femme</em>', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105082, 'fecha': datetime.datetime(2023, 11, 12, 11, 0), 'Total_Validadas': 260, 'nombre': 'Carolina Santiago', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105083, 'fecha': datetime.datetime(2023, 11, 13, 11, 0), 'Total_Validadas': 228, 'nombre': 'Carolina Santiago', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105275, 'fecha': datetime.datetime(2023, 11, 13, 17, 30), 'Total_Validadas': 277, 'nombre': 'El arte: entre el valor y el precio', 'formato': 'La cuestión palpitante'}
# {'idActo': 105269, 'fecha': datetime.datetime(2023, 11, 14, 17, 30), 'Total_Validadas': 269, 'nombre': 'La figura humana en la Antigüedad Figuras divinas. Lecturas y comprensión del cuerpo humano en el Egipto antiguo', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105043, 'fecha': datetime.datetime(2023, 11, 15, 17, 30), 'Total_Validadas': 282, 'nombre': 'Un siglo de música polaca El legado chopiniano', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105270, 'fecha': datetime.datetime(2023, 11, 16, 17, 30), 'Total_Validadas': 279, 'nombre': 'La figura humana en la Antigüedad La invención del cuerpo en la Grecia antigua', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105255, 'fecha': datetime.datetime(2023, 11, 17, 17, 0), 'Total_Validadas': 280, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>El código criminal</em> (1930) de Howard Hawks', 'formato': 'Cine en la March'}
# {'idActo': 105040, 'fecha': datetime.datetime(2023, 11, 18, 11, 0), 'Total_Validadas': 282, 'nombre': 'Cabaré: París-Berlín <em>Kabarett Berlin</em>', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105256, 'fecha': datetime.datetime(2023, 11, 18, 17, 0), 'Total_Validadas': 262, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>El código criminal</em> (1930) de Howard Hawks', 'formato': 'Cine en la March'}
# {'idActo': 105088, 'fecha': datetime.datetime(2023, 11, 19, 11, 0), 'Total_Validadas': 272, 'nombre': 'Rachel Fenlon', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105089, 'fecha': datetime.datetime(2023, 11, 20, 11, 0), 'Total_Validadas': 281, 'nombre': 'Rachel Fenlon', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105304, 'fecha': datetime.datetime(2023, 11, 20, 17, 30), 'Total_Validadas': 0, 'nombre': 'Carlos Muñoz de Pablos ', 'formato': 'Memorias de la Fundación'}
# {'idActo': 105271, 'fecha': datetime.datetime(2023, 11, 21, 17, 30), 'Total_Validadas': 242, 'nombre': 'La figura humana en la Antigüedad Los iberos y la imagen de la figura humana', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105044, 'fecha': datetime.datetime(2023, 11, 22, 17, 30), 'Total_Validadas': 282, 'nombre': 'Un siglo de música polaca Otoño de Varsovia', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105272, 'fecha': datetime.datetime(2023, 11, 23, 17, 30), 'Total_Validadas': 263, 'nombre': 'La figura humana en la Antigüedad La figura humana en el arte romano. El poder de la imagen.', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105385, 'fecha': datetime.datetime(2023, 11, 24, 17, 30), 'Total_Validadas': 280, 'nombre': 'Preestreno de <em>Cristina Garc&iacute;a Rodero: la mirada oculta</em>', 'formato': 'Cine y Arte'}
# {'idActo': 105041, 'fecha': datetime.datetime(2023, 11, 25, 11, 0), 'Total_Validadas': 282, 'nombre': 'Cabaré: París-Berlín Del cabaré al auditorio', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105090, 'fecha': datetime.datetime(2023, 11, 26, 11, 0), 'Total_Validadas': 276, 'nombre': 'Marta Puig', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105091, 'fecha': datetime.datetime(2023, 11, 27, 11, 0), 'Total_Validadas': 272, 'nombre': 'Marta Puig', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105364, 'fecha': datetime.datetime(2023, 11, 27, 17, 30), 'Total_Validadas': 191, 'nombre': 'Acerca de la exposici&oacute;n <em>Antes de Am&eacute;rica. Fuentes originarias en la cultura moderna</em>', 'formato': 'La exposición explicada'}
# {'idActo': 105054, 'fecha': datetime.datetime(2023, 11, 28, 9, 30), 'Total_Validadas': 283, 'nombre': 'Curso 2023-24 Escuchar la naturaleza [10:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105055, 'fecha': datetime.datetime(2023, 11, 28, 11, 30), 'Total_Validadas': 252, 'nombre': 'Curso 2023-24 Escuchar la naturaleza [12:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105362, 'fecha': datetime.datetime(2023, 11, 28, 17, 30), 'Total_Validadas': 282, 'nombre': 'De frontera a imperio, de imperio a nación. Una historia económica de España De frontera a imperio', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105045, 'fecha': datetime.datetime(2023, 11, 29, 17, 30), 'Total_Validadas': 278, 'nombre': 'Un siglo de música polaca Polskie Requiem', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105363, 'fecha': datetime.datetime(2023, 11, 30, 17, 30), 'Total_Validadas': 141, 'nombre': 'De frontera a imperio, de imperio a nación. Una historia económica de España De imperio a nación', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105257, 'fecha': datetime.datetime(2023, 12, 1, 17, 0), 'Total_Validadas': 261, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>Hampa dorada</em> (1931) de Mervyn LeRoy', 'formato': 'Cine en la March'}
# {'idActo': 105047, 'fecha': datetime.datetime(2023, 12, 2, 11, 0), 'Total_Validadas': 272, 'nombre': 'Conciertos en familia 2023-2024 Escuchar la naturaleza', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105258, 'fecha': datetime.datetime(2023, 12, 2, 17, 0), 'Total_Validadas': 259, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>Hampa dorada</em> (1931) de Mervyn LeRoy', 'formato': 'Cine en la March'}
# {'idActo': 105092, 'fecha': datetime.datetime(2023, 12, 3, 11, 0), 'Total_Validadas': 282, 'nombre': 'Ismael Campanero', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105093, 'fecha': datetime.datetime(2023, 12, 4, 11, 0), 'Total_Validadas': 282, 'nombre': 'Ismael Campanero', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105291, 'fecha': datetime.datetime(2023, 12, 4, 17, 30), 'Total_Validadas': 130, 'nombre': 'La financiación de la cultura', 'formato': 'La cuestión palpitante'}
# {'idActo': 105289, 'fecha': datetime.datetime(2023, 12, 5, 17, 30), 'Total_Validadas': 282, 'nombre': 'Maquiavelo: su vida, su obra, su tiempo Vida de Maquiavelo: el contexto', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105046, 'fecha': datetime.datetime(2023, 12, 6, 17, 30), 'Total_Validadas': 266, 'nombre': 'Aula de (Re)estrenos (123). Música electrónica vs. instrumental: diálogos de timbres', 'formato': 'Aula de (Re)estrenos'}
# {'idActo': 105290, 'fecha': datetime.datetime(2023, 12, 7, 17, 30), 'Total_Validadas': 276, 'nombre': 'Maquiavelo: su vida, su obra, su tiempo La teoría política de Maquiavelo', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105349, 'fecha': datetime.datetime(2023, 12, 11, 17, 30), 'nombre': 'Félix Vidal Costa', 'formato': 'Memorias de la Fundación'}
# {'idActo': 105323, 'fecha': datetime.datetime(2023, 12, 13, 17, 30), 'Total_Validadas': 271, 'nombre': '<em>La muerte y el industrial</em> de Jorge Fern&aacute;ndez Guerra', 'formato': 'Teatro Musical de Cámara'}
# {'idActo': 105324, 'fecha': datetime.datetime(2023, 12, 14, 17, 30), 'Total_Validadas': 260, 'nombre': '<em>La muerte y el industrial</em> de Jorge Fern&aacute;ndez Guerra', 'formato': 'Teatro Musical de Cámara'}
# {'idActo': 105379, 'fecha': datetime.datetime(2023, 12, 18, 15, 0), 'nombre': 'Antes de Am&eacute;rica en la gran pantalla. Fuentes originarias y modernidad cinematogr&aacute;fica <em>Raíces</em>', 'formato': 'Cine y Arte'}
# {'idActo': 105374, 'fecha': datetime.datetime(2023, 12, 18, 17, 0), 'nombre': 'Antes de Am&eacute;rica en la gran pantalla. Fuentes originarias y modernidad cinematogr&aacute;fica <em>¡Que Viva México!</em>', 'formato': 'Cine y Arte'}
# {'idActo': 105406, 'fecha': datetime.datetime(2024, 1, 8, 17, 30), 'Total_Validadas': 273, 'nombre': '<em>La Argentina en Par&iacute;s</em>, ballets de &Oacute;scar Espl&aacute; y Ernesto Halffter', 'formato': 'Teatro Musical de Cámara'}
# {'idActo': 105317, 'fecha': datetime.datetime(2024, 1, 9, 17, 30), 'Total_Validadas': 270, 'nombre': 'El control de los mares. Batallas navales de la Antig&uuml;edad a la Edad Moderna La batalla del Delta: soldados&nbsp;y marinos de Rams&eacute;s III frente a los Pueblos del Mar', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105407, 'fecha': datetime.datetime(2024, 1, 10, 17, 30), 'Total_Validadas': 273, 'nombre': 'La Argentina en París', 'formato': 'Teatro Musical de Cámara'}
# {'idActo': 105318, 'fecha': datetime.datetime(2024, 1, 11, 17, 30), 'Total_Validadas': 265, 'nombre': 'El control de los mares. Batallas navales de la Antig&uuml;edad a la Edad Moderna La batalla de Salamina (480 a. C.): remos y espolones contra el Gran Rey persa', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105408, 'fecha': datetime.datetime(2024, 1, 12, 17, 30), 'Total_Validadas': 273, 'nombre': 'La Argentina en París', 'formato': 'Teatro Musical de Cámara'}
# {'idActo': 105410, 'fecha': datetime.datetime(2024, 1, 13, 11, 0), 'Total_Validadas': 273, 'nombre': 'La Argentina en París', 'formato': 'Teatro Musical de Cámara'}
# {'idActo': 105409, 'fecha': datetime.datetime(2024, 1, 13, 17, 30), 'Total_Validadas': 273, 'nombre': 'La Argentina en París', 'formato': 'Teatro Musical de Cámara'}
# {'idActo': 105411, 'fecha': datetime.datetime(2024, 1, 14, 11, 0), 'Total_Validadas': 273, 'nombre': 'La Argentina en París', 'formato': 'Teatro Musical de Cámara'}
# {'idActo': 105431, 'fecha': datetime.datetime(2024, 1, 15, 17, 30), 'Total_Validadas': 163, 'nombre': 'Viejos y nuevos BRICS', 'formato': 'La cuestión palpitante'}
# {'idActo': 105319, 'fecha': datetime.datetime(2024, 1, 16, 17, 30), 'Total_Validadas': 282, 'nombre': 'El control de los mares. Batallas navales de la Antig&uuml;edad a la Edad Moderna El desastre naval cartagin&eacute;s en las islas Egadas (241 a. C.) y la moderna arqueolog&iacute;a subacu&aacute;tica', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105190, 'fecha': datetime.datetime(2024, 1, 17, 17, 30), 'Total_Validadas': 0, 'nombre': 'Perspectivas bartokianas Bartók en España', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105320, 'fecha': datetime.datetime(2024, 1, 18, 17, 30), 'Total_Validadas': 275, 'nombre': 'El control de los mares. Batallas navales de la Antig&uuml;edad a la Edad Moderna Actium: Octavio contra Marco Antonio y Cleopatra', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105074, 'fecha': datetime.datetime(2024, 1, 19, 17, 0), 'Total_Validadas': 282, 'nombre': 'Mil años de amor Amor melanc&oacute;lico: <em>chanson </em>y fado', 'formato': 'Viernes Temáticos'}
# {'idActo': 105193, 'fecha': datetime.datetime(2024, 1, 20, 11, 0), 'Total_Validadas': 282, 'nombre': 'En el centro del salón: arpas históricas Arpa sacra y profana', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105075, 'fecha': datetime.datetime(2024, 1, 20, 17, 0), 'Total_Validadas': 282, 'nombre': 'Mil años de amor Amor melanc&oacute;lico: <em>chanson </em>y fado', 'formato': 'Viernes Temáticos'}
# {'idActo': 105212, 'fecha': datetime.datetime(2024, 1, 21, 11, 0), 'Total_Validadas': 282, 'nombre': 'Trío Kalon', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105211, 'fecha': datetime.datetime(2024, 1, 22, 11, 0), 'Total_Validadas': 282, 'nombre': 'Trío Kalon', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105435, 'fecha': datetime.datetime(2024, 1, 22, 17, 30), 'Total_Validadas': 0, 'nombre': 'Vicente Salas Fum&aacute;s', 'formato': 'Memorias de la Fundación'}
# {'idActo': 105298, 'fecha': datetime.datetime(2024, 1, 23, 9, 30), 'Total_Validadas': 289, 'nombre': 'Curso 2023-24 Danza española: folclore, flamenco y sentimiento [10:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105299, 'fecha': datetime.datetime(2024, 1, 23, 11, 30), 'Total_Validadas': 276, 'nombre': 'Curso 2023-24 Danza española: folclore, flamenco y sentimiento [12:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105321, 'fecha': datetime.datetime(2024, 1, 23, 17, 30), 'Total_Validadas': 282, 'nombre': 'El control de los mares. Batallas navales de la Antig&uuml;edad a la Edad Moderna La batalla naval de La Rochela (1372)', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105189, 'fecha': datetime.datetime(2024, 1, 24, 17, 30), 'Total_Validadas': 282, 'nombre': 'Perspectivas bartokianas El Bartók coral, en contexto', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105322, 'fecha': datetime.datetime(2024, 1, 25, 17, 30), 'Total_Validadas': 282, 'nombre': 'El control de los mares. Batallas navales de la Antig&uuml;edad a la Edad Moderna La batalla de Lepanto', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105259, 'fecha': datetime.datetime(2024, 1, 26, 17, 0), 'Total_Validadas': 280, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>El enemigo p&uacute;blico</em>&nbsp;(1931) de William Wellman ', 'formato': 'Cine en la March'}
# {'idActo': 105194, 'fecha': datetime.datetime(2024, 1, 27, 11, 0), 'Total_Validadas': 282, 'nombre': 'En el centro del salón: arpas históricas El arpa de Ariadna', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105260, 'fecha': datetime.datetime(2024, 1, 27, 17, 0), 'Total_Validadas': 270, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>El enemigo p&uacute;blico</em>&nbsp;(1931) de William Wellman ', 'formato': 'Cine en la March'}
# {'idActo': 105213, 'fecha': datetime.datetime(2024, 1, 28, 11, 0), 'Total_Validadas': 282, 'nombre': 'Trío Schola', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105214, 'fecha': datetime.datetime(2024, 1, 29, 11, 0), 'Total_Validadas': 282, 'nombre': 'Trío Schola', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105382, 'fecha': datetime.datetime(2024, 1, 29, 15, 0), 'nombre': 'Antes de Am&eacute;rica en la gran pantalla. Fuentes originarias y modernidad cinematogr&aacute;fica <em>El secreto de los incas</em>', 'formato': 'Cine y Arte'}
# {'idActo': 105375, 'fecha': datetime.datetime(2024, 1, 29, 17, 30), 'nombre': 'Antes de Am&eacute;rica en la gran pantalla. Fuentes originarias y modernidad cinematogr&aacute;fica <em>El signo de la muerte</em>', 'formato': 'Cine y Arte'}
# {'idActo': 105294, 'fecha': datetime.datetime(2024, 1, 30, 17, 30), 'Total_Validadas': 257, 'nombre': 'John Ford: su vida, su obra, su tiempo John Ford: poeta y comediante', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105191, 'fecha': datetime.datetime(2024, 1, 31, 17, 30), 'Total_Validadas': 280, 'nombre': 'Perspectivas bartokianas El Bartók folclorista', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105295, 'fecha': datetime.datetime(2024, 2, 1, 17, 30), 'Total_Validadas': 277, 'nombre': 'John Ford: su vida, su obra, su tiempo <p>El cine seg&uacute;n John Ford</p>', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105195, 'fecha': datetime.datetime(2024, 2, 3, 11, 0), 'Total_Validadas': 281, 'nombre': 'En el centro del salón: arpas históricas El arpa, un instrumento femenino', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105215, 'fecha': datetime.datetime(2024, 2, 4, 11, 0), 'Total_Validadas': 282, 'nombre': 'Dúo Éire', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105216, 'fecha': datetime.datetime(2024, 2, 5, 11, 0), 'Total_Validadas': 271, 'nombre': 'Dúo Éire', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105376, 'fecha': datetime.datetime(2024, 2, 5, 15, 0), 'nombre': 'Antes de Am&eacute;rica en la gran pantalla. Fuentes originarias y modernidad cinematogr&aacute;fica <em>El signo de la muerte</em> ', 'formato': 'Cine y Arte'}
# {'idActo': 105380, 'fecha': datetime.datetime(2024, 2, 5, 17, 30), 'nombre': 'Antes de Am&eacute;rica en la gran pantalla. Fuentes originarias y modernidad cinematogr&aacute;fica <em>Raíces</em>', 'formato': 'Cine y Arte'}
# {'idActo': 105296, 'fecha': datetime.datetime(2024, 2, 6, 9, 30), 'Total_Validadas': 251, 'nombre': 'Curso 2023-24 Escuchar la naturaleza [10:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105297, 'fecha': datetime.datetime(2024, 2, 6, 11, 30), 'Total_Validadas': 275, 'nombre': 'Curso 2023-24 Escuchar la naturaleza [12:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105365, 'fecha': datetime.datetime(2024, 2, 6, 17, 30), 'Total_Validadas': 268, 'nombre': 'Francisco Giner de los Ríos: su vida, su obra, su tiempo Francisco Giner de los R&iacute;os: el primer espa&ntilde;ol moderno', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105192, 'fecha': datetime.datetime(2024, 2, 7, 17, 30), 'Total_Validadas': 282, 'nombre': 'Perspectivas bartokianas La cosmología pianística de Bartók', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105366, 'fecha': datetime.datetime(2024, 2, 8, 17, 30), 'Total_Validadas': 259, 'nombre': 'Francisco Giner de los Ríos: su vida, su obra, su tiempo El legado de Giner de los R&iacute;os', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105265, 'fecha': datetime.datetime(2024, 2, 9, 17, 0), 'Total_Validadas': 268, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>Dinero f&aacute;cil</em> (1931) de Alfred E. Green', 'formato': 'Cine en la March'}
# {'idActo': 105196, 'fecha': datetime.datetime(2024, 2, 10, 11, 0), 'Total_Validadas': 282, 'nombre': 'En el centro del salón: arpas históricas El arpa conquista la esfera pública', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105266, 'fecha': datetime.datetime(2024, 2, 10, 17, 0), 'Total_Validadas': 262, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>Dinero f&aacute;cil</em> (1931) de Alfred E. Green', 'formato': 'Cine en la March'}
# {'idActo': 105217, 'fecha': datetime.datetime(2024, 2, 11, 11, 0), 'Total_Validadas': 281, 'nombre': 'Anacronía', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105218, 'fecha': datetime.datetime(2024, 2, 12, 11, 0), 'Total_Validadas': 282, 'nombre': 'Anacronía', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105438, 'fecha': datetime.datetime(2024, 2, 12, 17, 30), 'Total_Validadas': 0, 'nombre': 'Antonio C&oacute;rdoba Barba', 'formato': 'Memorias de la Fundación'}
# {'idActo': 105387, 'fecha': datetime.datetime(2024, 2, 13, 17, 30), 'Total_Validadas': 282, 'nombre': 'Celtas. Un pueblo de hierro Los celtas en Europa: poblamiento y cultura', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105197, 'fecha': datetime.datetime(2024, 2, 14, 17, 30), 'Total_Validadas': 268, 'nombre': '124. Proyecto Conrado: integral de sus cuartetos (IV)', 'formato': 'Aula de (Re)estrenos'}
# {'idActo': 105388, 'fecha': datetime.datetime(2024, 2, 15, 17, 30), 'Total_Validadas': 275, 'nombre': 'Celtas. Un pueblo de hierro La historia genética de los celtas en Europa', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105414, 'fecha': datetime.datetime(2024, 2, 16, 17, 0), 'Total_Validadas': 282, 'nombre': 'Mil años de amor Amor místico', 'formato': 'Viernes Temáticos'}
# {'idActo': 105198, 'fecha': datetime.datetime(2024, 2, 17, 11, 0), 'Total_Validadas': 279, 'nombre': 'Nostalgias Contra el olvido', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105415, 'fecha': datetime.datetime(2024, 2, 17, 17, 0), 'Total_Validadas': 276, 'nombre': 'Mil años de amor Amor místico', 'formato': 'Viernes Temáticos'}
# {'idActo': 105219, 'fecha': datetime.datetime(2024, 2, 18, 11, 0), 'Total_Validadas': 282, 'nombre': 'Dúo Da Vinci de Google', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105220, 'fecha': datetime.datetime(2024, 2, 19, 11, 0), 'Total_Validadas': 282, 'nombre': 'Dúo Da Vinci de Google', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105461, 'fecha': datetime.datetime(2024, 2, 19, 17, 30), 'Total_Validadas': 132, 'nombre': 'El desempleo en Espa&ntilde;a', 'formato': 'La cuestión palpitante'}
# {'idActo': 105337, 'fecha': datetime.datetime(2024, 2, 20, 9, 30), 'Total_Validadas': 247, 'nombre': 'Curso 2023-24 Escuchar la naturaleza [10:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105338, 'fecha': datetime.datetime(2024, 2, 20, 11, 30), 'Total_Validadas': 207, 'nombre': 'Curso 2023-24 Escuchar la naturaleza [12:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105389, 'fecha': datetime.datetime(2024, 2, 20, 17, 30), 'Total_Validadas': 276, 'nombre': 'Celtas. Un pueblo de hierro Las lenguas de los celtas', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105202, 'fecha': datetime.datetime(2024, 2, 21, 17, 30), 'Total_Validadas': 280, 'nombre': 'Reinas de la música Isabel II, pianista ', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105390, 'fecha': datetime.datetime(2024, 2, 22, 17, 30), 'Total_Validadas': 269, 'nombre': 'Celtas. Un pueblo de hierro Druidismo, cosmolog&iacute;a y calendario en el mundo c&eacute;ltico', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105261, 'fecha': datetime.datetime(2024, 2, 23, 17, 0), 'Total_Validadas': 277, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>Las calles de la ciudad</em> (1931) de Rouben Mamoulian ', 'formato': 'Cine en la March'}
# {'idActo': 105199, 'fecha': datetime.datetime(2024, 2, 24, 11, 0), 'Total_Validadas': 282, 'nombre': 'Nostalgias Fado saudade', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105262, 'fecha': datetime.datetime(2024, 2, 24, 17, 0), 'Total_Validadas': 276, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>Las calles de la ciudad</em> (1931) de Rouben Mamoulian ', 'formato': 'Cine en la March'}
# {'idActo': 105221, 'fecha': datetime.datetime(2024, 2, 25, 11, 0), 'Total_Validadas': 282, 'nombre': 'La Camerata Chromatica', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105222, 'fecha': datetime.datetime(2024, 2, 26, 11, 0), 'Total_Validadas': 282, 'nombre': 'La Camerata Chromatica', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105545, 'fecha': datetime.datetime(2024, 2, 26, 17, 30), 'Total_Validadas': 0, 'nombre': 'Estella Matutes Juan', 'formato': 'Memorias de la Fundación'}
# {'idActo': 105391, 'fecha': datetime.datetime(2024, 2, 27, 17, 30), 'Total_Validadas': 267, 'nombre': 'Celtas. Un pueblo de hierro En busca de las religiones de la Céltica antigua', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105203, 'fecha': datetime.datetime(2024, 2, 28, 17, 30), 'Total_Validadas': 282, 'nombre': 'Reinas de la música Danzas para dos reinas: María Luisa de Saboya e Isabel de Farnesio', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105392, 'fecha': datetime.datetime(2024, 2, 29, 17, 30), 'Total_Validadas': 260, 'nombre': 'Celtas. Un pueblo de hierro El celtismo popular: mitos, leyendas y nuevos medios de comunicación', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105200, 'fecha': datetime.datetime(2024, 3, 2, 11, 0), 'Total_Validadas': 282, 'nombre': 'Nostalgias Un mar de memorias', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105223, 'fecha': datetime.datetime(2024, 3, 3, 11, 0), 'Total_Validadas': 282, 'nombre': 'Cuarteto Erinys', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105224, 'fecha': datetime.datetime(2024, 3, 4, 11, 0), 'Total_Validadas': 282, 'nombre': 'Cuarteto Erinys', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105378, 'fecha': datetime.datetime(2024, 3, 4, 15, 0), 'nombre': 'Antes de Am&eacute;rica en la gran pantalla. Fuentes originarias y modernidad cinematogr&aacute;fica <em>Deseada</em>', 'formato': 'Cine y Arte'}
# {'idActo': 105384, 'fecha': datetime.datetime(2024, 3, 4, 17, 30), 'nombre': 'Antes de Am&eacute;rica en la gran pantalla. Fuentes originarias y modernidad cinematogr&aacute;fica <em>La montaña sagrada</em>', 'formato': 'Cine y Arte'}
# {'idActo': 105424, 'fecha': datetime.datetime(2024, 3, 5, 17, 30), 'Total_Validadas': 282, 'nombre': 'La guerra de Troya: entre realidad y ficción La guerra de Troya y los hititas', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105204, 'fecha': datetime.datetime(2024, 3, 6, 17, 30), 'Total_Validadas': 282, 'nombre': 'Reinas de la música El Códice de las Huelgas', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105428, 'fecha': datetime.datetime(2024, 3, 7, 17, 30), 'Total_Validadas': 282, 'nombre': 'La guerra de Troya: entre realidad y ficción La guerra de Troya: arqueolog&iacute;a, historia e iconograf&iacute;a', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105416, 'fecha': datetime.datetime(2024, 3, 8, 17, 0), 'Total_Validadas': 282, 'nombre': 'Mil años de amor Los trovadores y el amor cortés', 'formato': 'Viernes Temáticos'}
# {'idActo': 105201, 'fecha': datetime.datetime(2024, 3, 9, 11, 0), 'Total_Validadas': 282, 'nombre': 'Nostalgias Lachrimae', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105417, 'fecha': datetime.datetime(2024, 3, 9, 17, 0), 'Total_Validadas': 282, 'nombre': 'Mil años de amor Los trovadores y el amor cortés', 'formato': 'Viernes Temáticos'}
# {'idActo': 105225, 'fecha': datetime.datetime(2024, 3, 10, 11, 0), 'Total_Validadas': 282, 'nombre': 'Quinteto Cierzo', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105226, 'fecha': datetime.datetime(2024, 3, 11, 11, 0), 'Total_Validadas': 272, 'nombre': 'Quinteto Cierzo', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105429, 'fecha': datetime.datetime(2024, 3, 12, 17, 30), 'Total_Validadas': 282, 'nombre': 'La guerra de Troya: entre realidad y ficción La <em>Il&iacute;ada</em> y la guerra de Troya', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105206, 'fecha': datetime.datetime(2024, 3, 13, 17, 30), 'Total_Validadas': 277, 'nombre': 'Mieczyslaw Weinberg: integral de los cuartetos de cuerda ', 'formato': 'Festival'}
# {'idActo': 105430, 'fecha': datetime.datetime(2024, 3, 14, 17, 30), 'Total_Validadas': 266, 'nombre': 'La guerra de Troya: entre realidad y ficción Antes y despu&eacute;s de la <em>Il&iacute;ada</em>: el Ciclo &eacute;pico', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105207, 'fecha': datetime.datetime(2024, 3, 15, 17, 30), 'Total_Validadas': 242, 'nombre': 'Mieczyslaw Weinberg: integral de los cuartetos de cuerda ', 'formato': 'Festival'}
# {'idActo': 105208, 'fecha': datetime.datetime(2024, 3, 16, 11, 0), 'Total_Validadas': 249, 'nombre': 'Mieczyslaw Weinberg: integral de los cuartetos de cuerda ', 'formato': 'Festival'}
# {'idActo': 105209, 'fecha': datetime.datetime(2024, 3, 16, 17, 30), 'Total_Validadas': 232, 'nombre': 'Mieczyslaw Weinberg: integral de los cuartetos de cuerda ', 'formato': 'Festival'}
# {'idActo': 105210, 'fecha': datetime.datetime(2024, 3, 17, 11, 0), 'Total_Validadas': 265, 'nombre': 'Mieczyslaw Weinberg: integral de los cuartetos de cuerda ', 'formato': 'Festival'}
# {'idActo': 105432, 'fecha': datetime.datetime(2024, 3, 18, 17, 30), 'Total_Validadas': 202, 'nombre': 'El español, su presente y futuro como lengua internacional', 'formato': 'La cuestión palpitante'}
# {'idActo': 105339, 'fecha': datetime.datetime(2024, 3, 19, 9, 30), 'Total_Validadas': 185, 'nombre': 'Curso 2023-24 Escuchar la naturaleza [10:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105368, 'fecha': datetime.datetime(2024, 3, 19, 17, 30), 'Total_Validadas': 232, 'nombre': 'Gilles Deleuze: su vida, su obra, su tiempo Deleuze como pensador: planos de fuga', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105205, 'fecha': datetime.datetime(2024, 3, 20, 17, 30), 'Total_Validadas': 282, 'nombre': 'Tríos y retratos: Castel y Goya', 'formato': 'Concierto Extraordinario'}
# {'idActo': 105367, 'fecha': datetime.datetime(2024, 3, 21, 17, 30), 'Total_Validadas': 156, 'nombre': 'Gilles Deleuze: su vida, su obra, su tiempo Los idus de mayo: el París de Deleuze', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105263, 'fecha': datetime.datetime(2024, 3, 22, 17, 0), 'Total_Validadas': 282, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>Scarface, el terror del hampa</em> (1932) de Howard Hawks ', 'formato': 'Cine en la March'}
# {'idActo': 105264, 'fecha': datetime.datetime(2024, 3, 23, 17, 0), 'Total_Validadas': 273, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>Scarface, el terror del hampa</em> (1932) de Howard Hawks ', 'formato': 'Cine en la March'}
# {'idActo': 105557, 'fecha': datetime.datetime(2024, 4, 2, 16, 30), 'Total_Validadas': 282, 'nombre': 'Simone de Beauvoir: su vida, su obra, su tiempo Simone de Beauvoir: su vida, su tiempo', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105483, 'fecha': datetime.datetime(2024, 4, 3, 16, 30), 'Total_Validadas': 281, 'nombre': 'Cabaré Pierrot', 'formato': 'Melodramas'}
# {'idActo': 105558, 'fecha': datetime.datetime(2024, 4, 4, 16, 30), 'Total_Validadas': 267, 'nombre': 'Simone de Beauvoir: su vida, su obra, su tiempo El feminismo que nació con Simone de Beauvoir', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105484, 'fecha': datetime.datetime(2024, 4, 6, 10, 0), 'Total_Validadas': 281, 'nombre': 'Cabaré Pierrot', 'formato': 'Melodramas'}
# {'idActo': 105485, 'fecha': datetime.datetime(2024, 4, 7, 10, 0), 'Total_Validadas': 281, 'nombre': 'Cabaré Pierrot', 'formato': 'Melodramas'}
# {'idActo': 105574, 'fecha': datetime.datetime(2024, 4, 8, 16, 30), 'Total_Validadas': 0, 'nombre': 'Emilio Casares', 'formato': 'Memorias de la Fundación'}
# {'idActo': 105559, 'fecha': datetime.datetime(2024, 4, 9, 16, 30), 'Total_Validadas': 282, 'nombre': 'Cuatro obras maestras de la historia de la m&uacute;sica <em>El Mes&iacute;as</em> de Handel', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105305, 'fecha': datetime.datetime(2024, 4, 10, 16, 30), 'Total_Validadas': 274, 'nombre': 'Cerrar los ojos ', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105560, 'fecha': datetime.datetime(2024, 4, 11, 16, 30), 'Total_Validadas': 282, 'nombre': 'Cuatro obras maestras de la historia de la m&uacute;sica La Misa en Si menor de Bach: final de trayecto', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105354, 'fecha': datetime.datetime(2024, 4, 13, 10, 0), 'Total_Validadas': 282, 'nombre': 'Historias del musical Musicales en <em>big band</em>', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105227, 'fecha': datetime.datetime(2024, 4, 14, 10, 0), 'Total_Validadas': 282, 'nombre': 'Cuarteto Synthèse', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105228, 'fecha': datetime.datetime(2024, 4, 15, 10, 0), 'Total_Validadas': 277, 'nombre': 'Cuarteto Synthèse', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105578, 'fecha': datetime.datetime(2024, 4, 15, 16, 30), 'Total_Validadas': 258, 'nombre': 'El sueño: importancia y trastornos', 'formato': 'La cuestión palpitante'}
# {'idActo': 105561, 'fecha': datetime.datetime(2024, 4, 16, 16, 30), 'Total_Validadas': 282, 'nombre': 'Cuatro obras maestras de la historia de la m&uacute;sica Paradojas del <em>R&eacute;quiem</em> de Mozart: la &oacute;pera en el templo', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105306, 'fecha': datetime.datetime(2024, 4, 17, 16, 30), 'Total_Validadas': 282, 'nombre': 'Cerrar los ojos ', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105562, 'fecha': datetime.datetime(2024, 4, 18, 16, 30), 'Total_Validadas': 282, 'nombre': 'Cuatro obras maestras de la historia de la m&uacute;sica La <em>Novena</em> de Beethoven: el abrazo que no cesa', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105419, 'fecha': datetime.datetime(2024, 4, 19, 16, 0), 'Total_Validadas': 265, 'nombre': 'Mil años de amor Amor mitológico: Adonis y Venus', 'formato': 'Viernes Temáticos'}
# {'idActo': 105355, 'fecha': datetime.datetime(2024, 4, 20, 10, 0), 'Total_Validadas': 282, 'nombre': 'Historias del musical Un armonicista en Broadway', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105420, 'fecha': datetime.datetime(2024, 4, 20, 16, 0), 'Total_Validadas': 266, 'nombre': 'Mil años de amor Amor mitológico: Adonis y Venus', 'formato': 'Viernes Temáticos'}
# {'idActo': 105229, 'fecha': datetime.datetime(2024, 4, 21, 10, 0), 'Total_Validadas': 282, 'nombre': 'Anna Urpina', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105230, 'fecha': datetime.datetime(2024, 4, 22, 10, 0), 'Total_Validadas': 280, 'nombre': 'Anna Urpina', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105581, 'fecha': datetime.datetime(2024, 4, 23, 16, 30), 'Total_Validadas': 268, 'nombre': 'Un siglo de expediciones cient&iacute;ficas espa&ntilde;olas Jorge Juan y la expedición al Ecuador para esclarecer la forma de la Tierra', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105307, 'fecha': datetime.datetime(2024, 4, 24, 16, 30), 'Total_Validadas': 280, 'nombre': 'Cerrar los ojos ', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105582, 'fecha': datetime.datetime(2024, 4, 25, 16, 30), 'Total_Validadas': 256, 'nombre': 'Un siglo de expediciones cient&iacute;ficas espa&ntilde;olas José Celestino Mutis: el héroe de las mil caras y la flora imaginaria', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105543, 'fecha': datetime.datetime(2024, 4, 26, 16, 30), 'Total_Validadas': 280, 'nombre': 'Inauguraci&oacute;n de la exposición «El peque&ntilde;o museo m&aacute;s bello del mundo»', 'formato': 'Acto inaugural'}
# {'idActo': 105356, 'fecha': datetime.datetime(2024, 4, 27, 10, 0), 'Total_Validadas': 282, 'nombre': 'Historias del musical De Gershwin a Cole Porter', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105231, 'fecha': datetime.datetime(2024, 4, 28, 10, 0), 'Total_Validadas': 282, 'nombre': 'Dennis Orellana, Sofía Gutiérrez-Tobar y Julen Jiménez', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105232, 'fecha': datetime.datetime(2024, 4, 29, 10, 0), 'Total_Validadas': 249, 'nombre': 'Dennis Orellana, Sofía Gutiérrez-Tobar y Julen Jiménez', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105300, 'fecha': datetime.datetime(2024, 4, 30, 8, 30), 'Total_Validadas': 270, 'nombre': 'Curso 2023-24 Danza española: folclore, flamenco y sentimiento [10:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105301, 'fecha': datetime.datetime(2024, 4, 30, 10, 30), 'Total_Validadas': 189, 'nombre': 'Curso 2023-24 Danza española: folclore, flamenco y sentimiento [12:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105583, 'fecha': datetime.datetime(2024, 4, 30, 16, 30), 'Total_Validadas': 274, 'nombre': 'Un siglo de expediciones cient&iacute;ficas espa&ntilde;olas La Real Expedición de la Vacuna vista por un virólogo', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105357, 'fecha': datetime.datetime(2024, 5, 4, 10, 0), 'Total_Validadas': 282, 'nombre': 'Historias del musical La época dorada del claqué', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105233, 'fecha': datetime.datetime(2024, 5, 5, 10, 0), 'Total_Validadas': 264, 'nombre': 'Maëlys Robinne', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105234, 'fecha': datetime.datetime(2024, 5, 6, 10, 0), 'Total_Validadas': 252, 'nombre': 'Maëlys Robinne', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105580, 'fecha': datetime.datetime(2024, 5, 6, 16, 30), 'Total_Validadas': 0, 'nombre': 'Álvaro Cuervo', 'formato': 'Memorias de la Fundación'}
# {'idActo': 105302, 'fecha': datetime.datetime(2024, 5, 7, 8, 30), 'Total_Validadas': 238, 'nombre': 'Curso 2023-24 Danza española: folclore, flamenco y sentimiento [10:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105303, 'fecha': datetime.datetime(2024, 5, 7, 10, 30), 'Total_Validadas': 254, 'nombre': 'Curso 2023-24 Danza española: foclore, flamenco y sentimiento [12:30]', 'formato': 'Conciertos didácticos'}
# {'idActo': 105590, 'fecha': datetime.datetime(2024, 5, 7, 16, 30), 'Total_Validadas': 258, 'nombre': 'Fernando Z&oacute;bel: su vida, su obra, su tiempo Fernando Zóbel, la pintura y la historia', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105308, 'fecha': datetime.datetime(2024, 5, 8, 16, 30), 'Total_Validadas': 277, 'nombre': 'Cerrar los ojos ', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105591, 'fecha': datetime.datetime(2024, 5, 9, 16, 30), 'Total_Validadas': 236, 'nombre': 'Fernando Z&oacute;bel: su vida, su obra, su tiempo La geografía de Fernando Zóbel', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105575, 'fecha': datetime.datetime(2024, 5, 10, 16, 30), 'Total_Validadas': 242, 'nombre': 'David Chipperfield', 'formato': 'Diálogos cosmopolitas'}
# {'idActo': 105492, 'fecha': datetime.datetime(2024, 5, 11, 10, 0), 'Total_Validadas': 282, 'nombre': 'Folk irlandés Melodías ancestrales sacuden al mundo', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105235, 'fecha': datetime.datetime(2024, 5, 12, 10, 0), 'Total_Validadas': 268, 'nombre': 'Cuartetos de violonchelos del RCSMM', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105236, 'fecha': datetime.datetime(2024, 5, 13, 10, 0), 'Total_Validadas': 280, 'nombre': 'Cuartetos de violonchelos del RCSMM', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105572, 'fecha': datetime.datetime(2024, 5, 13, 16, 30), 'Total_Validadas': 218, 'nombre': 'La polarizaci&oacute;n pol&iacute;tica', 'formato': 'La cuestión palpitante'}
# {'idActo': 105584, 'fecha': datetime.datetime(2024, 5, 14, 16, 30), 'Total_Validadas': 262, 'nombre': 'Los fenicios: navegantes entre Oriente y Occidente Los fenicios, entre el misterio y la realidad', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105309, 'fecha': datetime.datetime(2024, 5, 15, 16, 30), 'Total_Validadas': 282, 'nombre': 'El universo musical de García Lorca Lorca: in memoriam', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105585, 'fecha': datetime.datetime(2024, 5, 16, 16, 30), 'Total_Validadas': 278, 'nombre': 'Los fenicios: navegantes entre Oriente y Occidente Novedades arqueológicas sobre el mundo fenicio', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105421, 'fecha': datetime.datetime(2024, 5, 17, 16, 0), 'Total_Validadas': 282, 'nombre': 'Mil años de amor Boleros, penas de amor', 'formato': 'Viernes Temáticos'}
# {'idActo': 105493, 'fecha': datetime.datetime(2024, 5, 18, 10, 0), 'Total_Validadas': 282, 'nombre': 'Folk irlandés Folk tejido con el violín', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105422, 'fecha': datetime.datetime(2024, 5, 18, 16, 0), 'Total_Validadas': 282, 'nombre': 'Mil años de amor Boleros, penas de amor', 'formato': 'Viernes Temáticos'}
# {'idActo': 105237, 'fecha': datetime.datetime(2024, 5, 19, 10, 0), 'Total_Validadas': 270, 'nombre': 'Roman Borisov', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105238, 'fecha': datetime.datetime(2024, 5, 20, 10, 0), 'Total_Validadas': 281, 'nombre': 'Roman Borisov', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105603, 'fecha': datetime.datetime(2024, 5, 20, 16, 30), 'Total_Validadas': 207, 'nombre': 'Acerca de la exposici&oacute;n <em>&laquo;El peque&ntilde;o museo m&aacute;s bello del mundo&raquo;</em>', 'formato': 'La exposición explicada'}
# {'idActo': 105586, 'fecha': datetime.datetime(2024, 5, 21, 16, 30), 'Total_Validadas': 279, 'nombre': 'Los fenicios: navegantes entre Oriente y Occidente La religi&oacute;n fenicia', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105310, 'fecha': datetime.datetime(2024, 5, 22, 16, 30), 'Total_Validadas': 282, 'nombre': 'El universo musical de García Lorca Lorca en forma de canciones', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105587, 'fecha': datetime.datetime(2024, 5, 23, 16, 30), 'Total_Validadas': 254, 'nombre': 'Los fenicios: navegantes entre Oriente y Occidente Una fama bien merecida. Las actividades productivas de los fenicios', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105267, 'fecha': datetime.datetime(2024, 5, 24, 16, 0), 'Total_Validadas': 280, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>El enemigo p&uacute;blico n&uacute;mero 1</em> (1934) de W. S. Van Dyke ', 'formato': 'Cine en la March'}
# {'idActo': 105494, 'fecha': datetime.datetime(2024, 5, 25, 10, 0), 'Total_Validadas': 282, 'nombre': 'Folk irlandés Esencia viva: folk en otra piel', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105268, 'fecha': datetime.datetime(2024, 5, 25, 16, 0), 'Total_Validadas': 261, 'nombre': 'Cine de gangsters en el Hollywood <em>Pre-Code</em> <em>El enemigo p&uacute;blico n&uacute;mero 1</em> (1934) de W. S. Van Dyke ', 'formato': 'Cine en la March'}
# {'idActo': 105239, 'fecha': datetime.datetime(2024, 5, 26, 10, 0), 'Total_Validadas': 263, 'nombre': 'Cuarteto Chaos', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105240, 'fecha': datetime.datetime(2024, 5, 27, 10, 0), 'Total_Validadas': 275, 'nombre': 'Cuarteto Chaos', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105588, 'fecha': datetime.datetime(2024, 5, 28, 16, 30), 'Total_Validadas': 255, 'nombre': 'Los fenicios: navegantes entre Oriente y Occidente Los fenicios, su escritura y sus escritos', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105311, 'fecha': datetime.datetime(2024, 5, 29, 16, 30), 'Total_Validadas': 282, 'nombre': 'El universo musical de García Lorca Poemas lorquianos del cante jondo', 'formato': 'Ciclos de Miércoles'}
# {'idActo': 105589, 'fecha': datetime.datetime(2024, 5, 30, 16, 30), 'Total_Validadas': 259, 'nombre': 'Los fenicios: navegantes entre Oriente y Occidente Del Mediterráneo al Atlántico: la expansión fenicia', 'formato': 'Ciclos de conferencias'}
# {'idActo': 105048, 'fecha': datetime.datetime(2024, 6, 1, 9, 0), 'Total_Validadas': 282, 'nombre': 'Conciertos en familia 2023-2024 Danza española: folclore, flamenco y sentimiento', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105314, 'fecha': datetime.datetime(2024, 6, 1, 11, 0), 'Total_Validadas': 282, 'nombre': 'Conciertos en familia 2023-2024 Danza española: folclore, flamenco y sentimiento', 'formato': 'Conciertos del Sábado'}
# {'idActo': 105287, 'fecha': datetime.datetime(2024, 6, 2, 10, 0), 'Total_Validadas': 249, 'nombre': 'Álvaro Toscano', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105288, 'fecha': datetime.datetime(2024, 6, 3, 10, 0), 'Total_Validadas': 261, 'nombre': 'Álvaro Toscano', 'formato': 'Jóvenes intérpretes'}
# {'idActo': 105644, 'fecha': datetime.datetime(2024, 6, 4, 10, 0), 'Total_Validadas': 0, 'nombre': 'Programación especial de Radio Clásica desde la Fundación Juan March', 'formato': 'Actos especiales'}
# {'idActo': 105645, 'fecha': datetime.datetime(2024, 6, 4, 12, 0), 'Total_Validadas': 0, 'nombre': 'Programación especial de Radio Clásica desde la Fundación Juan March', 'formato': 'Actos especiales'}
# {'idActo': 105646, 'fecha': datetime.datetime(2024, 6, 4, 14, 0), 'Total_Validadas': 0, 'nombre': 'Programación especial de Radio Clásica desde la Fundación Juan March', 'formato': 'Actos especiales'}
# {'idActo': 105313, 'fecha': datetime.datetime(2024, 6, 5, 16, 30), 'Total_Validadas': 282, 'nombre': 'La emoción de las voces. Clausura de la temporada de conciertos 2023-2024', 'formato': 'Concierto Extraordinario'}
# {'idActo': 105737, 'fecha': datetime.datetime(2024, 7, 10, 16, 30), 'Total_Validadas': 20, 'nombre': 'La palabra dicha y dichosa La palabra dicha y dichosa. Actividades breves', 'formato': 'Festival'}
# {'idActo': 105707, 'fecha': datetime.datetime(2024, 7, 10, 18, 30), 'Total_Validadas': 267, 'nombre': 'La palabra dicha y dichosa La palabra del amor, la dicha del sentimiento', 'formato': 'Festival'}
# {'idActo': 105738, 'fecha': datetime.datetime(2024, 7, 11, 16, 30), 'Total_Validadas': 16, 'nombre': 'La palabra dicha y dichosa La palabra dicha y dichosa. Actividades breves', 'formato': 'Festival'}
# {'idActo': 105739, 'fecha': datetime.datetime(2024, 7, 11, 16, 30), 'Total_Validadas': 30, 'nombre': 'La palabra dicha y dichosa Que oy&eacute;ndolo se pueda saber todo', 'formato': 'Festival'}
# {'idActo': 105709, 'fecha': datetime.datetime(2024, 7, 11, 18, 30), 'Total_Validadas': 231, 'nombre': 'La palabra dicha y dichosa La palabra explicada, la dicha de la palabra viva', 'formato': 'Festival'}
# {'idActo': 105740, 'fecha': datetime.datetime(2024, 7, 12, 16, 30), 'Total_Validadas': 40, 'nombre': 'La palabra dicha y dichosa El sabor de las palabras', 'formato': 'Festival'}
# {'idActo': 105742, 'fecha': datetime.datetime(2024, 7, 12, 16, 30), 'Total_Validadas': 16, 'nombre': 'La palabra dicha y dichosa Biblioteca Humana', 'formato': 'Festival'}
# {'idActo': 105744, 'fecha': datetime.datetime(2024, 7, 12, 16, 30), 'Total_Validadas': 4, 'nombre': 'La palabra dicha y dichosa Aprende a pensar y a decir el verso', 'formato': 'Festival'}
# {'idActo': 105710, 'fecha': datetime.datetime(2024, 7, 12, 18, 30), 'Total_Validadas': 239, 'nombre': 'La palabra dicha y dichosa La palabra de la lucha, la dicha de la militancia', 'formato': 'Festival'}
# {'idActo': 105743, 'fecha': datetime.datetime(2024, 7, 13, 16, 30), 'Total_Validadas': 20, 'nombre': 'La palabra dicha y dichosa Biblioteca Humana', 'formato': 'Festival'}
# {'idActo': 105745, 'fecha': datetime.datetime(2024, 7, 13, 16, 30), 'Total_Validadas': 10, 'nombre': 'La palabra dicha y dichosa Aprende a pensar y a decir el verso', 'formato': 'Festival'}
# {'idActo': 105711, 'fecha': datetime.datetime(2024, 7, 13, 18, 30), 'Total_Validadas': 282, 'nombre': 'La palabra dicha y dichosa La palabra de la ausencia, la dicha de la soledad', 'formato': 'Festival'}
# {'idActo': 105741, 'fecha': datetime.datetime(2024, 7, 14, 8, 30), 'Total_Validadas': 40, 'nombre': 'La palabra dicha y dichosa El sabor de las palabras', 'formato': 'Festival'}
# {'idActo': 105712, 'fecha': datetime.datetime(2024, 7, 14, 10, 30), 'Total_Validadas': 282, 'nombre': 'La palabra dicha y dichosa La palabra en escena como un viaje a otros lugares', 'formato': 'Festival'}

# %%
import pandas as pd

df1 = pd.DataFrame(resultados)
df2 = pd.DataFrame(resultados2)

# Renombrar columnas si es necesario
df2 = df2.rename(columns={"idActo": "idacto"})


df_combinado = pd.merge(df1, df2, on="idacto", how="outer")

df_combinado = df_combinado.sort_values(by="fecha", ascending=True)  # Orden ascendente
df_combinado.to_excel("datos_ordenados.xlsx", index=False, engine="openpyxl")
#df_combinado
